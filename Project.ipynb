# %% [markdown]
# # PROJECT REPORT#
# * This project used data from The United States National Climatic Data Center, This data is the weather in Dallas from 01/1895 to 01/2017.
# * Table meaning:
#     * PCP - Precipitation Index
#     * TAVG - Temperature Index
#     * TMIN - Minimum Temperature Index
#     * TMAX - Maximum Temperature Index
#     * PDSI - Palmer Drought Severity Index
#     * PHDI - Palmer Hydrological Drought Index
#     * ZNDX - Palmer Z-Index
#     * PMDI - Modified Palmer Drought Severity Index
#     * CDD - Cooling Degree Days
#     * HDD - Heating Degree Days
#     * SPnn - Standard Precipitation Index

# %% [markdown]
# ### QUESTION 1: (Using Pandas, Numpy, matplotlib)
# How the temp, PCP, HDD, and CDD have been changed from 1895-2017?

# %%
import pandas as pd
import numpy as np
##import matplotlib.pyplot as plt
##import unicodecsv


df = pd.read_csv('TexasTemp.csv', index_col=0)

df.head()
# Out:
#            Division  YearMonth  TAVG  TMIN  TMAX   PCP  PDSI  PHDI  ZNDX  \
# StateCode
# 41                0     189501  44.6  31.2  57.9  1.30  0.32  0.32  0.97
# 41                0     189502  38.5  26.7  50.2  1.90  0.95  0.95  1.99
# 41                0     189503  56.4  43.1  69.7  0.88  0.56  0.56 -0.88
# 41                0     189504  64.8  50.0  79.6  1.38  0.26  0.26 -0.73
# 41                0     189505  69.7  57.8  81.6  4.96  1.20  1.20  2.89
#
#            PMDI    CDD    HDD  SP01   SP02   SP03   SP06   SP09   SP12   SP24
# StateCode
# 41         0.32   10.0  574.0 -0.13 -99.99 -99.99 -99.99 -99.99 -99.99 -99.99
# 41         0.95    0.0  686.0  0.48   0.18 -99.99 -99.99 -99.99 -99.99 -99.99
# 41         0.56   42.0  245.0 -0.99  -0.35  -0.36 -99.99 -99.99 -99.99 -99.99
# 41        -0.51  108.0   55.0 -0.76  -1.18  -0.67 -99.99 -99.99 -99.99 -99.99
# 41         1.20  211.0   10.0  1.19   0.47   0.08 -99.99 -99.99 -99.99 -99.99

# %%
df.tail()
# Out:
#            Division  YearMonth  TAVG  TMIN  TMAX   PCP  PDSI  PHDI  ZNDX  \
# StateCode
# 41                0     201609  77.6  66.7  88.5  2.99  5.13  5.13 -0.48
# 41                0     201610  70.9  57.7  84.1  0.69  3.63  3.63 -2.90
# 41                0     201611  61.1  49.6  72.5  2.38  3.15  3.15 -0.31
# 41                0     201612  49.6  38.9  60.3  2.14  2.87  2.87  0.14
# 41                0     201701  50.8  38.7  62.9  2.32  2.70  2.70  0.35
#
#            PMDI    CDD    HDD  SP01  SP02  SP03  SP06  SP09  SP12  SP24
# StateCode
# 41         4.90  450.0    0.0  0.15  1.58  0.93  1.74  1.42  2.14  2.90
# 41         2.28  258.0   13.0 -1.44 -0.80  0.55  0.68  1.12  1.32  2.84
# 41         1.68   98.0  122.0  0.61 -0.56 -0.43  0.38  1.30  1.11  2.94
# 41         1.45   19.0  387.0  0.55  0.63 -0.29  0.35  1.16  1.03  2.30
# 41         1.39   39.0  369.0  0.95  0.89  0.88  0.90  0.95  1.31  2.30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 41 to 41
# Data columns (total 19 columns):
# Division     1465 non-null int64
# YearMonth    1465 non-null int64
# TAVG         1465 non-null float64
# TMIN         1465 non-null float64
# TMAX         1465 non-null float64
# PCP          1465 non-null float64
# PDSI         1465 non-null float64
# PHDI         1465 non-null float64
# ZNDX         1465 non-null float64
# PMDI         1465 non-null float64
# CDD          1465 non-null float64
# HDD          1465 non-null float64
# SP01         1465 non-null float64
# SP02         1465 non-null float64
# SP03         1465 non-null float64
# SP06         1465 non-null float64
# SP09         1465 non-null float64
# SP12         1465 non-null float64
# SP24         1465 non-null float64
# dtypes: float64(17), int64(2)
# memory usage: 228.9 KB

# %% [markdown]
# This table below shows:
# There is 1465 months  from 01/1895 to 01/2017.
#
# The average temperature in 1465 months is 64.77 degree (Fahrenheit), the lowest average temperature is 36.6 degree, and the highest average temperature is 88.2 degree. Moreover, we can see that the lowest temperature from 1895-2017 is 24.1 degree and the highest temperature is 101.6 degree.
#
# The average PHP in 1465 months is 2.26, the lowest is 0.02, and the highest is 9.05

# %%
df.describe()
# Out:
#        Division      YearMonth         TAVG         TMIN         TMAX  \
# count    1465.0    1465.000000  1465.000000  1465.000000  1465.000000
# mean        0.0  195560.694198    64.772355    52.330512    77.204505
# std         0.0    3525.377025    13.506872    13.648677    13.480776
# min         0.0  189501.000000    36.600000    24.100000    46.800000
# 25%         0.0  192507.000000    52.000000    39.500000    64.700000
# 50%         0.0  195601.000000    65.400000    52.700000    78.600000
# 75%         0.0  198607.000000    77.900000    66.100000    89.800000
# max         0.0  201701.000000    88.200000    74.700000   101.600000
#
#                PCP         PDSI         PHDI         ZNDX         PMDI  \
# count  1465.000000  1465.000000  1465.000000  1465.000000  1465.000000
# mean      2.265154    -0.142314    -0.065659    -0.025317    -0.083208
# std       1.276177     2.958140     3.093609     1.973357     2.955770
# min       0.020000    -8.050000    -8.050000    -5.570000    -8.050000
# 25%       1.300000    -2.360000    -2.490000    -1.460000    -2.380000
# 50%       2.070000    -0.340000     0.370000    -0.210000    -0.030000
# 75%       2.950000     2.150000     2.400000     1.220000     2.160000
# max       9.050000     8.230000     8.230000     8.330000     8.230000
#
#                CDD          HDD         SP01         SP02         SP03  \
# count  1465.000000  1465.000000  1465.000000  1465.000000  1465.000000
# mean    221.707850   169.031399     0.002526    -0.066280    -0.136437
# std     214.889381   203.507070     0.989223     2.792369     3.823301
# min       0.000000     0.000000    -3.040000   -99.990000   -99.990000
# 25%      21.000000     0.000000    -0.700000    -0.690000    -0.700000
# 50%     131.000000    57.000000     0.010000    -0.020000    -0.030000
# 75%     428.000000   331.000000     0.690000     0.720000     0.710000
# max     750.000000   834.000000     3.090000     3.090000     3.090000
#
#               SP06         SP09         SP12         SP24
# count  1465.000000  1465.000000  1465.000000  1465.000000
# mean     -0.339823    -0.545672    -0.752348    -1.565973
# std       5.916969     7.437500     8.691142    12.476734
# min     -99.990000   -99.990000   -99.990000   -99.990000
# 25%      -0.720000    -0.740000    -0.720000    -0.660000
# 50%       0.000000     0.010000     0.010000     0.040000
# 75%       0.690000     0.670000     0.680000     0.640000
# max       3.010000     2.880000     3.090000     3.080000

# %% [markdown]
# This code below changed the fomart of Yeahmothe from int to datetime format:

# %%
from datetime import datetime as dt
import unicodecsv

with open('TexasTemp.csv', 'rb') as f:
    reader = unicodecsv.DictReader(f)
    ymdates = list(reader)

def parse_date(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%Y%m')
for ymdate in ymdates:
    ymdate['YearMonth'] = parse_date(ymdate['YearMonth'])
ymdates[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-23417f8872f1> in <module>()
#       3
#       4 with open('TexasTemp.csv', 'rb') as f:
# ----> 5     reader = unicodecsv.DictReader(f)
#       6     ymdates = list(reader)
#       7
#
# NameError: name 'unicodecsv' is not defined

# %% [markdown]
# This is a data table, and chart of average temperature, max temp, and min temp by each month in from 01/1895 to 01/2017:

# %%
df[["YearMonth", "TAVG","TMIN","TMAX"]].groupby(['YearMonth'], as_index=False).mean().sort_values(by='YearMonth', ascending=True)

# %%
import matplotlib.pyplot as plt

plt.plot(df["YearMonth"], df["TAVG"])
plt.xlabel('Time(YearMonth)')
plt.ylabel('Temp')
plt.title('TempvsTime')
plt.show()

# %% [markdown]
# This plot show the change of temperature in each month from 01/1895 to 01/2017. From this plot, we can see that the temp have been increased. From 19300s to 19400s, the temperature seem to droped to lowest temperatures in few months. However, in the summer of each years, we can see that the temperatures of those months had been increase litle bit. In this case, this is the effect of global warming from Pre-industrial era

# %%
df[["YearMonth", "CDD", "HDD"]].groupby(['YearMonth'], as_index=False).mean().sort_values(by='YearMonth', ascending=True)

# %%
import matplotlib.pyplot as plt

plt.plot(df["YearMonth"], df["CDD"])
plt.xlabel('Time(YearMonth)')
plt.ylabel('CDD')
plt.title('CDDvsTime')
plt.figure(figsize=(20,10))
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(df["YearMonth"], df["HDD"])
plt.xlabel('Time(YearMonth)')
plt.ylabel('HDD')
plt.title('HDDvsTime')
plt.figure(figsize=(20,10))
plt.show()

# %%
df[["YearMonth", "PCP"]].groupby(['YearMonth'], as_index=False).mean().sort_values(by='YearMonth', ascending=True)

# %%
import matplotlib.pyplot as plt

plt.plot(df["YearMonth"], df["PCP"])
plt.xlabel('Time(YearMonth)')
plt.ylabel('PCP')
plt.title('PCPvsTime')
plt.figure(figsize=(20,10))
plt.show()

# %% [markdown]
# ### QUESTION 2 (Using MapReduce)
# *What is the month has highest temp from 1895 - 2017?
#
#     *In order to run TexasTemp Dataset on Mapreduce, I edit the TexasTemp.csv file by removing the first row "the name of collum" then save it to a new file "TexasTempNone.csv"

# %%
# %%file maxTemp.py

from mrjob.job import MRJob
from mrjob.step import MRStep

class maxTemp(MRJob):
    def steps(self):
        return [
            MRStep(mapper=self.mapper_get_ratings,
                 reducer=self.reducer_count_ratings),
           MRStep(mapper=self.mapper_passthrough,
                 reducer = self.reducer_find_max)
        ]

    def mapper_get_ratings(self, _, line):
        (StateCode, Division, YearMonth, tavg, tmin, tmax, pcp, pdsi, phdi, zndx, pmdi,cdd, hdd, sp01, sp02, sp03, sp06, sp09, sp12, sp24) = line.split(",")
        yield YearMonth,float(tmax)
              
    def mapper_passthrough(self, key, values):
        yield key, values    
    
    def reducer_count_ratings(self, key, values):
        yield None, (max(values), key)
        
    def reducer_find_max(self, key, values):
        yield  max(values)
    
if __name__ == '__main__':
    maxTemp.run()
# Out:
# Overwriting maxTemp.py

# %%
# !python maxTemp.py TexasTempNone.csv
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /var/folders/8h/_r5sr0qn5kb7bfj_9dmvj9hh0000gn/T/maxTemp.longdang2709.20170508.041352.894182
# Running step 1 of 2...
# Running step 2 of 2...
# Streaming final output from /var/folders/8h/_r5sr0qn5kb7bfj_9dmvj9hh0000gn/T/maxTemp.longdang2709.20170508.041352.894182/output...
# 101.6	"201108"
# Removing temp directory /var/folders/8h/_r5sr0qn5kb7bfj_9dmvj9hh0000gn/T/maxTemp.longdang2709.20170508.041352.894182...

# %% [markdown]
# The highest temperature is 101.6 in 08/2011

# %% [markdown]
# ### QUESTION 3: (Using SprakPy)
# What is the most common average temperature from 1895-2017?
# In order to work with SprakPy, I activated the python 2.7

# %%
# %%file commonTemp.py

from pyspark import SparkConf, SparkContext

conf = SparkConf().setMaster("local").setAppName("PopularTemp")
sc = SparkContext(conf = conf)

lines = sc.textFile("TexasTempNone.csv")
temps = lines.map(lambda x: (float(x.split(',')[3]), 1))
tempCounts = temps.reduceByKey(lambda x, y: x + y)

flipped = tempCounts.map(lambda (x,y) : (y,x) )
sortedTemp = flipped.sortByKey()

results = sortedTemp.collect()

for result in results:
    print(result)
# Out:
# Overwriting commonTemp.py

# %%
# !spark-submit commonTemp.py
# Out:
# 17/05/07 23:17:07 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# [Stage 0:>                                                          (0 + 2) / 2]/usr/local/Cellar/apache-spark/2.1.0/libexec/python/lib/pyspark.zip/pyspark/shuffle.py:58: UserWarning: Please install psutil to have better support with spilling
# /usr/local/Cellar/apache-spark/2.1.0/libexec/python/lib/pyspark.zip/pyspark/shuffle.py:58: UserWarning: Please install psutil to have better support with spilling
# (1, 38.5)
# (1, 38.4)
# (1, 38.0)
# (1, 46.0)
# (1, 60.5)
# (1, 60.9)
# (1, 62.2)
# (1, 41.5)
# (1, 70.5)
# (1, 66.4)
# (1, 73.8)
# (1, 61.9)
# (1, 62.4)
# (1, 83.5)
# (1, 56.0)
# (1, 74.8)
# (1, 85.4)
# (1, 77.8)
# (1, 69.9)
# (1, 52.7)
# (1, 39.7)
# (1, 40.7)
# (1, 54.0)
# (1, 86.4)
# (1, 61.4)
# (1, 74.9)
# (1, 38.7)
# (1, 51.4)
# (1, 43.4)
# (1, 78.9)
# (1, 54.9)
# (1, 57.7)
# (1, 53.9)
# (1, 37.2)
# (1, 63.5)
# (1, 54.4)
# (1, 42.7)
# (1, 43.9)
# (1, 42.5)
# (1, 59.9)
# (1, 54.7)
# (1, 41.7)
# (1, 39.9)
# (1, 60.2)
# (1, 41.4)
# (1, 42.2)
# (1, 44.4)
# (1, 58.5)
# (1, 57.4)
# (1, 60.4)
# (1, 67.0)
# (1, 68.7)
# (1, 76.6)
# (1, 71.0)
# (1, 87.0)
# (1, 40.1)
# (1, 36.6)
# (1, 46.6)
# (1, 88.2)
# (1, 66.1)
# (1, 41.8)
# (1, 84.6)
# (1, 85.6)
# (1, 63.1)
# (1, 60.1)
# (1, 36.8)
# (1, 62.3)
# (1, 66.2)
# (1, 59.3)
# (1, 42.1)
# (1, 59.1)
# (1, 72.2)
# (1, 61.6)
# (1, 73.2)
# (1, 57.8)
# (1, 44.3)
# (1, 62.1)
# (1, 55.6)
# (1, 42.8)
# (1, 68.6)
# (1, 86.1)
# (1, 60.3)
# (1, 48.6)
# (1, 52.1)
# (1, 60.8)
# (1, 85.0)
# (2, 67.8)
# (2, 42.0)
# (2, 68.8)
# (2, 44.9)
# (2, 50.5)
# (2, 62.0)
# (2, 61.5)
# (2, 70.0)
# (2, 72.0)
# (2, 74.0)
# (2, 50.2)
# (2, 46.7)
# (2, 59.2)
# (2, 84.3)
# (2, 76.5)
# (2, 47.2)
# (2, 50.4)
# (2, 68.3)
# (2, 40.2)
# (2, 69.4)
# (2, 84.5)
# (2, 57.2)
# (2, 60.7)
# (2, 47.5)
# (2, 71.4)
# (2, 44.5)
# (2, 58.4)
# (2, 62.9)
# (2, 67.5)
# (2, 83.9)
# (2, 75.4)
# (2, 43.2)
# (2, 76.3)
# (2, 84.9)
# (2, 43.7)
# (2, 56.4)
# (2, 39.2)
# (2, 73.6)
# (2, 46.3)
# (2, 41.0)
# (2, 49.0)
# (2, 59.0)
# (2, 84.2)
# (2, 85.2)
# (2, 69.7)
# (2, 65.1)
# (2, 72.7)
# (2, 53.1)
# (2, 49.8)
# (2, 54.1)
# (2, 43.6)
# (2, 45.8)
# (2, 54.6)
# (2, 62.8)
# (2, 44.8)
# (2, 55.1)
# (2, 76.7)
# (2, 77.7)
# (2, 70.1)
# (2, 43.1)
# (2, 56.6)
# (2, 41.6)
# (2, 65.2)
# (2, 73.1)
# (2, 58.1)
# (2, 40.8)
# (2, 58.6)
# (2, 67.2)
# (2, 84.7)
# (2, 65.7)
# (2, 78.1)
# (2, 60.6)
# (2, 71.2)
# (2, 64.6)
# (2, 74.2)
# (2, 63.3)
# (2, 75.2)
# (2, 76.2)
# (2, 69.6)
# (2, 38.3)
# (3, 42.4)
# (3, 49.5)
# (3, 61.7)
# (3, 58.9)
# (3, 65.5)
# (3, 50.0)
# (3, 66.5)
# (3, 69.8)
# (3, 78.4)
# (3, 76.0)
# (3, 80.0)
# (3, 70.8)
# (3, 84.0)
# (3, 62.5)
# (3, 65.9)
# (3, 47.7)
# (3, 66.9)
# (3, 46.9)
# (3, 67.9)
# (3, 51.2)
# (3, 56.2)
# (3, 63.9)
# (3, 43.5)
# (3, 70.9)
# (3, 78.8)
# (3, 59.7)
# (3, 48.9)
# (3, 53.7)
# (3, 78.5)
# (3, 74.5)
# (3, 77.3)
# (3, 57.5)
# (3, 67.4)
# (3, 42.9)
# (3, 83.8)
# (3, 58.7)
# (3, 51.9)
# (3, 84.4)
# (3, 70.3)
# (3, 63.4)
# (3, 64.4)
# (3, 72.3)
# (3, 71.3)
# (3, 73.3)
# (3, 78.3)
# (3, 44.7)
# (3, 76.8)
# (3, 56.9)
# (3, 45.2)
# (3, 58.2)
# (3, 64.8)
# (3, 45.7)
# (3, 73.4)
# (3, 57.9)
# (3, 61.3)
# (3, 74.6)
# (3, 46.8)
# (3, 67.7)
# (3, 55.0)
# (3, 63.0)
# (3, 52.6)
# (3, 65.0)
# (3, 77.0)
# (3, 79.0)
# (3, 48.3)
# (3, 71.7)
# (3, 50.3)
# (3, 67.1)
# (3, 50.8)
# (3, 75.7)
# (3, 56.1)
# (3, 44.1)
# (3, 72.1)
# (3, 80.7)
# (3, 53.8)
# (3, 63.6)
# (3, 75.1)
# (3, 50.1)
# (3, 56.3)
# (3, 69.2)
# (3, 40.3)
# (3, 43.3)
# (3, 85.1)
# (3, 45.6)
# (3, 70.6)
# (3, 54.3)
# (4, 52.0)
# (4, 58.0)
# (4, 68.0)
# (4, 68.5)
# (4, 79.4)
# (4, 51.5)
# (4, 75.3)
# (4, 65.8)
# (4, 49.7)
# (4, 45.9)
# (4, 77.9)
# (4, 72.5)
# (4, 76.9)
# (4, 73.5)
# (4, 47.4)
# (4, 68.9)
# (4, 51.7)
# (4, 75.5)
# (4, 63.7)
# (4, 71.9)
# (4, 77.5)
# (4, 72.9)
# (4, 52.2)
# (4, 55.9)
# (4, 55.7)
# (4, 82.5)
# (4, 52.4)
# (4, 56.7)
# (4, 53.4)
# (4, 65.4)
# (4, 81.9)
# (4, 45.5)
# (4, 46.5)
# (4, 75.9)
# (4, 81.5)
# (4, 61.8)
# (4, 80.6)
# (4, 66.7)
# (4, 45.0)
# (4, 53.0)
# (4, 51.1)
# (4, 75.0)
# (4, 83.0)
# (4, 70.7)
# (4, 49.3)
# (4, 66.6)
# (4, 53.6)
# (4, 62.6)
# (4, 73.7)
# (4, 68.1)
# (4, 69.1)
# (4, 51.8)
# (4, 78.7)
# (4, 54.8)
# (4, 68.2)
# (4, 76.1)
# (4, 55.3)
# (4, 57.6)
# (4, 79.1)
# (4, 56.8)
# (4, 45.1)
# (4, 61.1)
# (4, 51.6)
# (4, 84.1)
# (4, 77.2)
# (4, 43.8)
# (4, 47.8)
# (4, 79.2)
# (4, 49.1)
# (5, 48.5)
# (5, 71.5)
# (5, 79.5)
# (5, 82.3)
# (5, 62.7)
# (5, 63.2)
# (5, 76.4)
# (5, 77.4)
# (5, 78.0)
# (5, 82.0)
# (5, 71.8)
# (5, 45.4)
# (5, 64.9)
# (5, 72.8)
# (5, 52.5)
# (5, 48.4)
# (5, 54.5)
# (5, 64.3)
# (5, 49.4)
# (5, 80.8)
# (5, 56.5)
# (5, 73.9)
# (5, 66.3)
# (5, 55.2)
# (5, 75.8)
# (5, 59.5)
# (5, 74.3)
# (5, 67.3)
# (5, 72.4)
# (5, 81.3)
# (5, 46.1)
# (5, 72.6)
# (5, 49.6)
# (5, 50.6)
# (5, 51.0)
# (5, 57.0)
# (5, 77.6)
# (5, 79.6)
# (5, 52.8)
# (5, 44.6)
# (5, 82.6)
# (5, 81.1)
# (5, 65.6)
# (5, 45.3)
# (5, 58.3)
# (5, 83.6)
# (5, 71.6)
# (5, 51.3)
# (6, 46.2)
# (6, 47.9)
# (6, 64.0)
# (6, 82.4)
# (6, 80.4)
# (6, 81.4)
# (6, 83.4)
# (6, 66.8)
# (6, 55.5)
# (6, 79.8)
# (6, 82.8)
# (6, 79.9)
# (6, 79.3)
# (6, 48.7)
# (6, 64.7)
# (6, 81.2)
# (6, 81.0)
# (6, 78.6)
# (6, 48.8)
# (6, 75.6)
# (6, 53.3)
# (6, 83.7)
# (6, 77.1)
# (6, 57.3)
# (6, 47.1)
# (7, 48.0)
# (7, 65.3)
# (7, 52.9)
# (7, 80.9)
# (7, 48.2)
# (7, 55.4)
# (7, 82.2)
# (7, 83.2)
# (7, 63.8)
# (7, 81.6)
# (7, 79.7)
# (7, 64.2)
# (7, 47.6)
# (7, 78.2)
# (7, 80.2)
# (8, 74.4)
# (8, 44.0)
# (8, 81.8)
# (8, 46.4)
# (8, 83.3)
# (8, 74.1)
# (8, 47.3)
# (8, 82.1)
# (9, 64.5)
# (9, 66.0)
# (9, 49.2)
# (9, 53.2)
# (9, 80.5)
# (9, 50.9)
# (9, 80.3)
# (9, 80.1)
# (10, 50.7)
# (10, 82.7)
# (10, 83.1)
# (12, 82.9)
# (12, 81.7)

# %% [markdown]
# The most common temperatures are 82.9 and 81. 7, both of them was recorded 12 times from 1895-2017

# %% [markdown]
# ### QUESTION 4: (Using Hive)
# *What is most common HDD and CDD from 1895-2017?
#
# *Under file: "record_1_QUESTION4.txt"

# %% [raw]
# Script started on Thu 04 May 2017 03:18:17 AM EDT
# ]0;training@localhost:~[?1034h[training@localhost ~]$ hive
# Logging initialized using configuration in file:/etc/hive/conf.dist/hive-log4j.properties
# Hive history file=/tmp/training/hive_job_log_training_201705040318_1255778188.txt
#
# hive> CREATE DATABASE texasTemp;
# OK
# Time taken: 2.754 seconds
#
# hive> CREATE EXTERNAL TABLE texasTemp_external(sc INT, division INT, yearmonth INT, tavg FLOAT, tmin FLOAT, tmax FLOAT, pcp FLOAT, pdsi FLOAT, phdi FLOAT, zndx FLOAT, pmdi FLOAT, cdd FLOAT, hdd FLOAT, sp01 FLOAT, sp02 FLOAT, sp03 FLOAT, sp06 FLOAT, sp09 FLOAT, sp12 FLOAT, sp24 FLOAT) COMMENT 'EXTERNAL texasTemp' ROW FORMAT DELIMITED FIELDS TERMINATED BY ',' LOCATION '/home/training/HIVE/';
# OK
# Time taken: 0.242 seconds
#
# hive> CREATE TABLE texasTemp_internal(sc INT, division INT, yearmonth FLOAT, tavg FLOAT, tmin FLOAT, tman FLOAT, pcp FLOAT, pdsi FLOAT, phdi FLOAT, zndx FLOAT, pmdi FLOAT, cdd FLOAT, hdd FLOAT, sp01 FLOAT, sp02 FLOAT, sp03 FLOAT, sp06 FLOAT, sp09 FLOAT, sp12 FLOAT, sp24 FLOAT) COMMENT 'This is the INTERNAL texasTemp' ROW FORMAT DELIMITED FIELDS TERMINATED BY ',';
# LOAD DATA LOCAL INPATH '/home/training/HIVE/TexasTempNone.csv' INTO TABLE texasTemp_internal;
# OK
# Time taken: 0.072 seconds
# Copying data from file:/home/training/HIVE/TexasTempNone.csv
# Copying file: file:/home/training/HIVE/TexasTempNone.csv
# Loading data to table default.texastemp_internal
# OK
# Time taken: 0.52 seconds
#
# hive> DESC texasTemp_external;
# OK
# sc	int
# division	int
# yearmonth	int
# tavg	float
# tmin	float
# tmax	float
# pcp	float
# pdsi	float
# phdi	float
# zndx	float
# pmdi	float
# cdd	float
# hdd	float
# sp01	float
# sp02	float
# sp03	float
# sp06	float
# sp09	float
# sp12	float
# sp24	float
# Time taken: 0.174 seconds
#
# hive> DESC EXTENDED texasTemp_external;
# OK
# sc	int
# division	int
# yearmonth	int
# tavg	float
# tmin	float
# tmax	float
# pcp	float
# pdsi	float
# phdi	float
# zndx	float
# pmdi	float
# cdd	float
# hdd	float
# sp01	float
# sp02	float
# sp03	float
# sp06	float
# sp09	float
# sp12	float
# sp24	float
#
# Detailed Table Information	Table(tableName:texastemp_external, dbName:default, owner:training, createTime:1493882334, lastAccessTime:0, retention:0, sd:StorageDescriptor(cols:[FieldSchema(name:sc, type:int, comment:null), FieldSchema(name:division, type:int, comment:null), FieldSchema(name:yearmonth, type:int, comment:null), FieldSchema(name:tavg, type:float, comment:null), FieldSchema(name:tmin, type:float, comment:null), FieldSchema(name:tmax, type:float, comment:null), FieldSchema(name:pcp, type:float, comment:null), FieldSchema(name:pdsi, type:float, comment:null), FieldSchema(name:phdi, type:float, comment:null), FieldSchema(name:zndx, type:float, comment:null), FieldSchema(name:pmdi, type:float, comment:null), FieldSchema(name:cdd, type:float, comment:null), FieldSchema(name:hdd, type:float, comment:null), FieldSchema(name:sp01, type:float, comment:null), FieldSchema(name:sp02, type:float, comment:null), FieldSchema(name:sp03, type:float, comment:null), FieldSchema(name:sp06, type:float, comment:null), FieldSchema(name:sp09, type:float, comment:null), FieldSchema(name:sp12, type:float, comment:null), FieldSchema(name:sp24, type:float, comment:null)], location:hdfs://0.0.0.0:8020/home/training/HIVE, inputFormat:org.apache.hadoop.mapred.TextInputFormat, outputFormat:org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat, compressed:false, numBuckets:-1, serdeInfo:SerDeInfo(name:null, serializationLib:org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe, parameters:{serialization.format=,, field.delim=,}), bucketCols:[], sortCols:[], parameters:{}), partitionKeys:[], parameters:{EXTERNAL=TRUE, transient_lastDdlTime=1493882334, comment=EXTERNAL texasTemp}, viewOriginalText:null, viewExpandedText:null, tableType:EXTERNAL_TABLE)
# Time taken: 0.098 seconds
#
# hive> DESC EXTENDED texasTemp_internal;
# OK
# sc	int
# division	int
# yearmonth	float
# tavg	float
# tmin	float
# tman	float
# pcp	float
# pdsi	float
# phdi	float
# zndx	float
# pmdi	float
# cdd	float
# hdd	float
# sp01	float
# sp02	float
# sp03	float
# sp06	float
# sp09	float
# sp12	float
# sp24	float
#
# Detailed Table Information	Table(tableName:texastemp_internal, dbName:default, owner:training, createTime:1493882348, lastAccessTime:0, retention:0, sd:StorageDescriptor(cols:[FieldSchema(name:sc, type:int, comment:null), FieldSchema(name:division, type:int, comment:null), FieldSchema(name:yearmonth, type:float, comment:null), FieldSchema(name:tavg, type:float, comment:null), FieldSchema(name:tmin, type:float, comment:null), FieldSchema(name:tman, type:float, comment:null), FieldSchema(name:pcp, type:float, comment:null), FieldSchema(name:pdsi, type:float, comment:null), FieldSchema(name:phdi, type:float, comment:null), FieldSchema(name:zndx, type:float, comment:null), FieldSchema(name:pmdi, type:float, comment:null), FieldSchema(name:cdd, type:float, comment:null), FieldSchema(name:hdd, type:float, comment:null), FieldSchema(name:sp01, type:float, comment:null), FieldSchema(name:sp02, type:float, comment:null), FieldSchema(name:sp03, type:float, comment:null), FieldSchema(name:sp06, type:float, comment:null), FieldSchema(name:sp09, type:float, comment:null), FieldSchema(name:sp12, type:float, comment:null), FieldSchema(name:sp24, type:float, comment:null)], location:hdfs://0.0.0.0:8020/user/hive/warehouse/texastemp_internal, inputFormat:org.apache.hadoop.mapred.TextInputFormat, outputFormat:org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat, compressed:false, numBuckets:-1, serdeInfo:SerDeInfo(name:null, serializationLib:org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe, parameters:{serialization.format=,, field.delim=,}), bucketCols:[], sortCols:[], parameters:{}), partitionKeys:[], parameters:{transient_lastDdlTime=1493882349, comment=This is the INTERNAL texasTemp}, viewOriginalText:null, viewExpandedText:null, tableType:MANAGED_TABLE)
# Time taken: 0.09 seconds
#
# hive> SELECT cdd, COUNT(*) as a FROM texasTemp_internal GROUP BY cdd ORDER BY a;
# Total MapReduce jobs = 2
# Launching Job 1 out of 2
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapred.reduce.tasks=<number>
# Starting Job = job_201705040307_0007, Tracking URL = http://0.0.0.0:50030/jobdetails.jsp?jobid=job_201705040307_0007
# Kill Command = /usr/lib/hadoop/bin/hadoop job  -Dmapred.job.tracker=0.0.0.0:8021 -kill job_201705040307_0007
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# 2017-05-04 03:20:01,292 Stage-1 map = 0%,  reduce = 0%
# 2017-05-04 03:20:04,347 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 0.72 sec
# 2017-05-04 03:20:05,361 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 0.72 sec
# 2017-05-04 03:20:06,372 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 1.54 sec
# 2017-05-04 03:20:07,389 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 1.54 sec
# 2017-05-04 03:20:08,405 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 1.54 sec
# MapReduce Total cumulative CPU time: 1 seconds 540 msec
# Ended Job = job_201705040307_0007
# Launching Job 2 out of 2
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapred.reduce.tasks=<number>
# Starting Job = job_201705040307_0008, Tracking URL = http://0.0.0.0:50030/jobdetails.jsp?jobid=job_201705040307_0008
# Kill Command = /usr/lib/hadoop/bin/hadoop job  -Dmapred.job.tracker=0.0.0.0:8021 -kill job_201705040307_0008
# Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# 2017-05-04 03:20:11,811 Stage-2 map = 0%,  reduce = 0%
# 2017-05-04 03:20:13,833 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 0.6 sec
# 2017-05-04 03:20:14,840 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 0.6 sec
# 2017-05-04 03:20:15,852 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 1.34 sec
# 2017-05-04 03:20:16,861 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 1.34 sec
# 2017-05-04 03:20:17,869 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 1.34 sec
# MapReduce Total cumulative CPU time: 1 seconds 340 msec
# Ended Job = job_201705040307_0008
# MapReduce Jobs Launched:
# Job 0: Map: 1  Reduce: 1   Cumulative CPU: 1.54 sec   HDFS Read: 0 HDFS Write: 0 SUCCESS
# Job 1: Map: 1  Reduce: 1   Cumulative CPU: 1.34 sec   HDFS Read: 0 HDFS Write: 0 SUCCESS
# Total MapReduce CPU Time Spent: 2 seconds 880 msec
# OK
# 750.0	1
# 57.0	1
# 60.0	1
# 61.0	1
# 67.0	1
# 71.0	1
# 76.0	1
# 80.0	1
# 81.0	1
# 82.0	1
# 84.0	1
# 102.0	1
# 117.0	1
# 122.0	1
# 123.0	1
# 125.0	1
# 126.0	1
# 134.0	1
# 135.0	1
# 139.0	1
# 142.0	1
# 144.0	1
# 148.0	1
# 149.0	1
# 151.0	1
# 152.0	1
# 153.0	1
# 154.0	1
# 155.0	1
# 157.0	1
# 162.0	1
# 164.0	1
# 170.0	1
# 174.0	1
# 176.0	1
# 177.0	1
# 178.0	1
# 179.0	1
# 185.0	1
# 187.0	1
# 188.0	1
# 189.0	1
# 190.0	1
# 191.0	1
# 195.0	1
# 197.0	1
# 198.0	1
# 200.0	1
# 201.0	1
# 204.0	1
# 208.0	1
# 213.0	1
# 217.0	1
# 222.0	1
# 224.0	1
# 226.0	1
# 227.0	1
# 231.0	1
# 233.0	1
# 235.0	1
# 237.0	1
# 241.0	1
# 242.0	1
# 245.0	1
# 252.0	1
# 253.0	1
# 255.0	1
# 258.0	1
# 262.0	1
# 263.0	1
# 268.0	1
# 270.0	1
# 273.0	1
# 277.0	1
# 283.0	1
# 285.0	1
# 286.0	1
# 288.0	1
# 289.0	1
# 290.0	1
# 296.0	1
# 297.0	1
# 299.0	1
# 301.0	1
# 303.0	1
# 304.0	1
# 307.0	1
# 311.0	1
# 312.0	1
# 313.0	1
# 314.0	1
# 315.0	1
# 317.0	1
# 318.0	1
# 320.0	1
# 321.0	1
# 322.0	1
# 325.0	1
# 335.0	1
# 336.0	1
# 342.0	1
# 343.0	1
# 344.0	1
# 348.0	1
# 349.0	1
# 351.0	1
# 355.0	1
# 356.0	1
# 358.0	1
# 360.0	1
# 362.0	1
# 363.0	1
# 365.0	1
# 367.0	1
# 368.0	1
# 369.0	1
# 375.0	1
# 379.0	1
# 381.0	1
# 382.0	1
# 384.0	1
# 385.0	1
# 389.0	1
# 390.0	1
# 391.0	1
# 393.0	1
# 395.0	1
# 396.0	1
# 397.0	1
# 399.0	1
# 402.0	1
# 404.0	1
# 405.0	1
# 409.0	1
# 415.0	1
# 417.0	1
# 420.0	1
# 421.0	1
# 423.0	1
# 424.0	1
# 425.0	1
# 428.0	1
# 430.0	1
# 431.0	1
# 434.0	1
# 440.0	1
# 446.0	1
# 448.0	1
# 449.0	1
# 451.0	1
# 456.0	1
# 458.0	1
# 462.0	1
# 468.0	1
# 469.0	1
# 471.0	1
# 472.0	1
# 474.0	1
# 479.0	1
# 483.0	1
# 485.0	1
# 497.0	1
# 498.0	1
# 499.0	1
# 500.0	1
# 501.0	1
# 502.0	1
# 505.0	1
# 509.0	1
# 515.0	1
# 523.0	1
# 527.0	1
# 528.0	1
# 535.0	1
# 538.0	1
# 540.0	1
# 543.0	1
# 552.0	1
# 554.0	1
# 555.0	1
# 558.0	1
# 562.0	1
# 563.0	1
# 569.0	1
# 575.0	1
# 579.0	1
# 584.0	1
# 588.0	1
# 593.0	1
# 599.0	1
# 602.0	1
# 613.0	1
# 615.0	1
# 616.0	1
# 619.0	1
# 621.0	1
# 622.0	1
# 624.0	1
# 629.0	1
# 632.0	1
# 634.0	1
# 639.0	1
# 640.0	1
# 641.0	1
# 642.0	1
# 643.0	1
# 645.0	1
# 650.0	1
# 653.0	1
# 656.0	1
# 661.0	1
# 669.0	1
# 687.0	1
# 696.0	1
# 254.0	2
# 478.0	2
# 259.0	2
# 480.0	2
# 481.0	2
# 265.0	2
# 266.0	2
# 274.0	2
# 275.0	2
# 276.0	2
# 486.0	2
# 282.0	2
# 488.0	2
# 490.0	2
# 491.0	2
# 493.0	2
# 291.0	2
# 292.0	2
# 496.0	2
# 623.0	2
# 585.0	2
# 630.0	2
# 589.0	2
# 504.0	2
# 316.0	2
# 507.0	2
# 319.0	2
# 508.0	2
# 511.0	2
# 328.0	2
# 331.0	2
# 333.0	2
# 514.0	2
# 592.0	2
# 340.0	2
# 517.0	2
# 345.0	2
# 520.0	2
# 522.0	2
# 352.0	2
# 617.0	2
# 525.0	2
# 594.0	2
# 530.0	2
# 532.0	2
# 371.0	2
# 372.0	2
# 373.0	2
# 374.0	2
# 377.0	2
# 380.0	2
# 537.0	2
# 598.0	2
# 627.0	2
# 541.0	2
# 386.0	2
# 544.0	2
# 392.0	2
# 37.0	2
# 41.0	2
# 47.0	2
# 51.0	2
# 54.0	2
# 55.0	2
# 56.0	2
# 547.0	2
# 58.0	2
# 59.0	2
# 548.0	2
# 549.0	2
# 400.0	2
# 75.0	2
# 550.0	2
# 551.0	2
# 628.0	2
# 87.0	2
# 88.0	2
# 89.0	2
# 91.0	2
# 110.0	2
# 115.0	2
# 121.0	2
# 411.0	2
# 413.0	2
# 127.0	2
# 129.0	2
# 130.0	2
# 131.0	2
# 133.0	2
# 603.0	2
# 416.0	2
# 141.0	2
# 604.0	2
# 556.0	2
# 145.0	2
# 557.0	2
# 606.0	2
# 559.0	2
# 560.0	2
# 427.0	2
# 561.0	2
# 429.0	2
# 156.0	2
# 608.0	2
# 432.0	2
# 433.0	2
# 171.0	2
# 436.0	2
# 437.0	2
# 438.0	2
# 439.0	2
# 182.0	2
# 447.0	2
# 193.0	2
# 196.0	2
# 609.0	2
# 570.0	2
# 452.0	2
# 207.0	2
# 455.0	2
# 210.0	2
# 211.0	2
# 571.0	2
# 572.0	2
# 218.0	2
# 219.0	2
# 573.0	2
# 465.0	2
# 230.0	2
# 574.0	2
# 234.0	2
# 611.0	2
# 238.0	2
# 240.0	2
# 578.0	2
# 248.0	2
# 476.0	2
# 477.0	2
# 565.0	3
# 459.0	3
# 378.0	3
# 536.0	3
# 453.0	3
# 223.0	3
# 136.0	3
# 183.0	3
# 545.0	3
# 566.0	3
# 180.0	3
# 53.0	3
# 146.0	3
# 147.0	3
# 441.0	3
# 442.0	3
# 567.0	3
# 246.0	3
# 62.0	3
# 63.0	3
# 475.0	3
# 464.0	3
# 66.0	3
# 576.0	3
# 68.0	3
# 69.0	3
# 34.0	3
# 401.0	3
# 73.0	3
# 194.0	3
# 568.0	3
# 77.0	3
# 78.0	3
# 260.0	3
# 40.0	3
# 403.0	3
# 607.0	3
# 158.0	3
# 407.0	3
# 601.0	3
# 269.0	3
# 143.0	3
# 583.0	3
# 85.0	3
# 86.0	3
# 160.0	3
# 161.0	3
# 281.0	3
# 466.0	3
# 487.0	3
# 90.0	3
# 163.0	3
# 93.0	3
# 95.0	3
# 293.0	3
# 294.0	3
# 494.0	3
# 96.0	3
# 300.0	3
# 302.0	3
# 98.0	3
# 587.0	3
# 99.0	3
# 503.0	3
# 101.0	3
# 408.0	3
# 506.0	3
# 103.0	3
# 105.0	3
# 510.0	3
# 106.0	3
# 326.0	3
# 329.0	3
# 108.0	3
# 332.0	3
# 232.0	3
# 111.0	3
# 516.0	3
# 114.0	3
# 518.0	3
# 519.0	3
# 43.0	3
# 350.0	3
# 553.0	3
# 120.0	3
# 138.0	3
# 410.0	3
# 596.0	3
# 168.0	3
# 531.0	3
# 412.0	3
# 534.0	3
# 450.0	3
# 137.0	3
# 173.0	3
# 591.0	4
# 414.0	4
# 118.0	4
# 39.0	4
# 546.0	4
# 46.0	4
# 586.0	4
# 48.0	4
# 49.0	4
# 339.0	4
# 113.0	4
# 542.0	4
# 107.0	4
# 580.0	4
# 79.0	4
# 92.0	4
# 492.0	4
# 150.0	4
# 444.0	4
# 359.0	4
# 94.0	4
# 387.0	4
# 28.0	4
# 533.0	4
# 42.0	4
# 495.0	4
# 597.0	4
# 104.0	4
# 166.0	4
# 97.0	4
# 36.0	5
# 65.0	5
# 70.0	5
# 72.0	5
# 261.0	5
# 484.0	5
# 109.0	5
# 116.0	5
# 524.0	5
# 26.0	5
# 32.0	5
# 64.0	6
# 167.0	6
# 29.0	6
# 27.0	6
# 590.0	7
# 100.0	7
# 582.0	7
# 52.0	7
# 50.0	7
# 2.0	7
# 23.0	7
# 25.0	7
# 38.0	7
# 44.0	7
# 30.0	7
# 33.0	7
# 0.0	7
# 24.0	8
# 21.0	9
# 45.0	9
# 22.0	9
# 35.0	10
# 31.0	10
# 15.0	10
# 11.0	12
# 18.0	12
# 4.0	12
# 16.0	13
# 19.0	14
# 14.0	14
# 20.0	15
# 17.0	15
# 13.0	16
# 3.0	16
# 12.0	19
# 7.0	21
# 1.0	22
# 8.0	22
# 5.0	25
# 10.0	26
# 9.0	28
# 6.0	33
# Time taken: 19.795 seconds
#
#
# hive> SELECT hdd, COUNT(*) as b FROM texasTemp_internal GROUP BY hdd ORDER BY b;
# Total MapReduce jobs = 2
# Launching Job 1 out of 2
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapred.reduce.tasks=<number>
# Starting Job = job_201705040307_0009, Tracking URL = http://0.0.0.0:50030/jobdetails.jsp?jobid=job_201705040307_0009
# Kill Command = /usr/lib/hadoop/bin/hadoop job  -Dmapred.job.tracker=0.0.0.0:8021 -kill job_201705040307_0009
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# 2017-05-04 03:20:30,258 Stage-1 map = 0%,  reduce = 0%
# 2017-05-04 03:20:33,284 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 0.71 sec
# 2017-05-04 03:20:34,293 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 0.71 sec
# 2017-05-04 03:20:35,304 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 1.59 sec
# 2017-05-04 03:20:36,314 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 1.59 sec
# 2017-05-04 03:20:37,322 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 1.59 sec
# MapReduce Total cumulative CPU time: 1 seconds 590 msec
# Ended Job = job_201705040307_0009
# Launching Job 2 out of 2
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapred.reduce.tasks=<number>
# Starting Job = job_201705040307_0010, Tracking URL = http://0.0.0.0:50030/jobdetails.jsp?jobid=job_201705040307_0010
# Kill Command = /usr/lib/hadoop/bin/hadoop job  -Dmapred.job.tracker=0.0.0.0:8021 -kill job_201705040307_0010
# Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# 2017-05-04 03:20:39,707 Stage-2 map = 0%,  reduce = 0%
# 2017-05-04 03:20:42,721 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 0.62 sec
# 2017-05-04 03:20:43,726 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 0.62 sec
# 2017-05-04 03:20:44,732 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 1.38 sec
# 2017-05-04 03:20:45,739 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 1.38 sec
# 2017-05-04 03:20:46,745 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 1.38 sec
# MapReduce Total cumulative CPU time: 1 seconds 380 msec
# Ended Job = job_201705040307_0010
# MapReduce Jobs Launched:
# Job 0: Map: 1  Reduce: 1   Cumulative CPU: 1.59 sec   HDFS Read: 0 HDFS Write: 0 SUCCESS
# Job 1: Map: 1  Reduce: 1   Cumulative CPU: 1.38 sec   HDFS Read: 0 HDFS Write: 0 SUCCESS
# Total MapReduce CPU Time Spent: 2 seconds 970 msec
# OK
# 480.0	1
# 485.0	1
# 642.0	1
# 491.0	1
# 492.0	1
# 493.0	1
# 499.0	1
# 500.0	1
# 501.0	1
# 502.0	1
# 505.0	1
# 507.0	1
# 508.0	1
# 584.0	1
# 515.0	1
# 524.0	1
# 526.0	1
# 527.0	1
# 529.0	1
# 537.0	1
# 543.0	1
# 544.0	1
# 545.0	1
# 546.0	1
# 549.0	1
# 554.0	1
# 555.0	1
# 557.0	1
# 559.0	1
# 563.0	1
# 569.0	1
# 570.0	1
# 574.0	1
# 576.0	1
# 577.0	1
# 578.0	1
# 698.0	1
# 695.0	1
# 639.0	1
# 636.0	1
# 635.0	1
# 634.0	1
# 621.0	1
# 620.0	1
# 72.0	1
# 15.0	1
# 75.0	1
# 77.0	1
# 619.0	1
# 610.0	1
# 797.0	1
# 18.0	1
# 87.0	1
# 789.0	1
# 89.0	1
# 91.0	1
# 93.0	1
# 95.0	1
# 99.0	1
# 104.0	1
# 105.0	1
# 107.0	1
# 108.0	1
# 788.0	1
# 123.0	1
# 128.0	1
# 129.0	1
# 130.0	1
# 133.0	1
# 137.0	1
# 138.0	1
# 688.0	1
# 140.0	1
# 141.0	1
# 142.0	1
# 148.0	1
# 149.0	1
# 151.0	1
# 155.0	1
# 156.0	1
# 160.0	1
# 161.0	1
# 162.0	1
# 163.0	1
# 164.0	1
# 167.0	1
# 168.0	1
# 172.0	1
# 173.0	1
# 687.0	1
# 177.0	1
# 185.0	1
# 187.0	1
# 188.0	1
# 189.0	1
# 194.0	1
# 609.0	1
# 196.0	1
# 198.0	1
# 604.0	1
# 200.0	1
# 24.0	1
# 204.0	1
# 205.0	1
# 206.0	1
# 207.0	1
# 208.0	1
# 210.0	1
# 211.0	1
# 213.0	1
# 214.0	1
# 217.0	1
# 218.0	1
# 223.0	1
# 225.0	1
# 25.0	1
# 227.0	1
# 228.0	1
# 229.0	1
# 232.0	1
# 233.0	1
# 27.0	1
# 241.0	1
# 242.0	1
# 243.0	1
# 244.0	1
# 482.0	1
# 686.0	1
# 249.0	1
# 770.0	1
# 254.0	1
# 257.0	1
# 258.0	1
# 260.0	1
# 261.0	1
# 264.0	1
# 265.0	1
# 266.0	1
# 269.0	1
# 273.0	1
# 30.0	1
# 748.0	1
# 284.0	1
# 287.0	1
# 685.0	1
# 291.0	1
# 293.0	1
# 296.0	1
# 680.0	1
# 299.0	1
# 301.0	1
# 305.0	1
# 308.0	1
# 312.0	1
# 313.0	1
# 316.0	1
# 834.0	1
# 318.0	1
# 600.0	1
# 320.0	1
# 745.0	1
# 325.0	1
# 326.0	1
# 328.0	1
# 332.0	1
# 732.0	1
# 335.0	1
# 675.0	1
# 337.0	1
# 599.0	1
# 671.0	1
# 341.0	1
# 342.0	1
# 343.0	1
# 344.0	1
# 346.0	1
# 40.0	1
# 349.0	1
# 350.0	1
# 352.0	1
# 670.0	1
# 355.0	1
# 356.0	1
# 357.0	1
# 594.0	1
# 359.0	1
# 362.0	1
# 363.0	1
# 364.0	1
# 731.0	1
# 367.0	1
# 708.0	1
# 370.0	1
# 371.0	1
# 372.0	1
# 374.0	1
# 375.0	1
# 376.0	1
# 44.0	1
# 378.0	1
# 379.0	1
# 666.0	1
# 386.0	1
# 591.0	1
# 389.0	1
# 704.0	1
# 397.0	1
# 406.0	1
# 408.0	1
# 410.0	1
# 411.0	1
# 412.0	1
# 414.0	1
# 420.0	1
# 664.0	1
# 423.0	1
# 426.0	1
# 427.0	1
# 428.0	1
# 662.0	1
# 432.0	1
# 433.0	1
# 661.0	1
# 437.0	1
# 587.0	1
# 439.0	1
# 655.0	1
# 441.0	1
# 443.0	1
# 652.0	1
# 448.0	1
# 449.0	1
# 453.0	1
# 455.0	1
# 459.0	1
# 585.0	1
# 462.0	1
# 463.0	1
# 56.0	1
# 469.0	1
# 470.0	1
# 471.0	1
# 472.0	1
# 474.0	1
# 475.0	1
# 476.0	1
# 479.0	1
# 267.0	2
# 447.0	2
# 270.0	2
# 271.0	2
# 158.0	2
# 272.0	2
# 345.0	2
# 466.0	2
# 391.0	2
# 277.0	2
# 484.0	2
# 278.0	2
# 280.0	2
# 487.0	2
# 392.0	2
# 285.0	2
# 286.0	2
# 495.0	2
# 176.0	2
# 393.0	2
# 180.0	2
# 181.0	2
# 504.0	2
# 182.0	2
# 506.0	2
# 183.0	2
# 184.0	2
# 601.0	2
# 513.0	2
# 186.0	2
# 518.0	2
# 519.0	2
# 520.0	2
# 521.0	2
# 522.0	2
# 395.0	2
# 290.0	2
# 396.0	2
# 59.0	2
# 191.0	2
# 530.0	2
# 60.0	2
# 534.0	2
# 580.0	2
# 292.0	2
# 540.0	2
# 478.0	2
# 295.0	2
# 398.0	2
# 47.0	2
# 548.0	2
# 402.0	2
# 551.0	2
# 34.0	2
# 586.0	2
# 302.0	2
# 303.0	2
# 562.0	2
# 304.0	2
# 565.0	2
# 568.0	2
# 407.0	2
# 209.0	2
# 306.0	2
# 575.0	2
# 589.0	2
# 212.0	2
# 309.0	2
# 35.0	2
# 13.0	2
# 63.0	2
# 216.0	2
# 640.0	2
# 451.0	2
# 11.0	2
# 220.0	2
# 221.0	2
# 314.0	2
# 454.0	2
# 413.0	2
# 73.0	2
# 369.0	2
# 245.0	2
# 16.0	2
# 415.0	2
# 321.0	2
# 79.0	2
# 416.0	2
# 235.0	2
# 26.0	2
# 83.0	2
# 19.0	2
# 86.0	2
# 602.0	2
# 239.0	2
# 417.0	2
# 90.0	2
# 48.0	2
# 456.0	2
# 94.0	2
# 329.0	2
# 96.0	2
# 97.0	2
# 331.0	2
# 100.0	2
# 457.0	2
# 246.0	2
# 247.0	2
# 333.0	2
# 422.0	2
# 122.0	2
# 250.0	2
# 251.0	2
# 458.0	2
# 382.0	2
# 131.0	2
# 132.0	2
# 383.0	2
# 135.0	2
# 424.0	2
# 385.0	2
# 340.0	2
# 262.0	2
# 465.0	2
# 446.0	2
# 146.0	2
# 147.0	2
# 388.0	2
# 317.0	3
# 17.0	3
# 20.0	3
# 21.0	3
# 29.0	3
# 31.0	3
# 36.0	3
# 37.0	3
# 42.0	3
# 43.0	3
# 46.0	3
# 57.0	3
# 61.0	3
# 62.0	3
# 64.0	3
# 74.0	3
# 76.0	3
# 81.0	3
# 82.0	3
# 85.0	3
# 88.0	3
# 112.0	3
# 139.0	3
# 174.0	3
# 203.0	3
# 226.0	3
# 236.0	3
# 240.0	3
# 248.0	3
# 252.0	3
# 275.0	3
# 276.0	3
# 289.0	3
# 298.0	3
# 300.0	3
# 310.0	3
# 323.0	3
# 334.0	3
# 336.0	3
# 339.0	3
# 348.0	3
# 354.0	3
# 366.0	3
# 368.0	3
# 377.0	3
# 384.0	3
# 390.0	3
# 399.0	3
# 418.0	3
# 421.0	3
# 430.0	3
# 436.0	3
# 440.0	3
# 445.0	3
# 464.0	3
# 473.0	3
# 486.0	3
# 528.0	3
# 533.0	3
# 581.0	3
# 536.0	4
# 511.0	4
# 460.0	4
# 450.0	4
# 438.0	4
# 387.0	4
# 358.0	4
# 338.0	4
# 319.0	4
# 237.0	4
# 195.0	4
# 78.0	4
# 70.0	4
# 67.0	4
# 66.0	4
# 65.0	4
# 55.0	4
# 54.0	4
# 45.0	4
# 41.0	4
# 39.0	4
# 32.0	4
# 23.0	4
# 22.0	4
# 12.0	4
# 14.0	5
# 9.0	5
# 10.0	5
# 71.0	5
# 33.0	5
# 68.0	5
# 288.0	5
# 199.0	5
# 69.0	5
# 80.0	5
# 49.0	6
# 434.0	6
# 38.0	6
# 58.0	7
# 28.0	7
# 53.0	7
# 51.0	8
# 8.0	9
# 5.0	10
# 4.0	16
# 3.0	18
# 7.0	18
# 2.0	20
# 6.0	21
# 1.0	70
# 0.0	403
# Time taken: 19.176 seconds
#
# hive> SHOW TABLES;
# OK
# texastemp_external
# texastemp_internal
# Time taken: 0.079 seconds
#
# hive> SHOW DAA TABASES;
# OK
# default
# texastemp
# Time taken: 0.061 seconds
#
# hive> DROP TABLE texasTemp_internal;
# DROP TABLE texasTemp_external;
# OK
# Time taken: 0.344 seconds
#
# OK
# Time taken: 0.105 seconds
#
# hive> SHOW TABLES;
# OK
# Time taken: 0.075 seconds
#
# hive> DROP DATABASE texasTemp;
# OK
# Time taken: 0.072 seconds
#
# hive> SHW OW DATABASES;
# OK
# default
# Time taken: 0.069 seconds
#
# hive> ]0;training@localhost:~[training@localhost ~]$ exit
# exit
#
# Script done on Thu 04 May 2017 03:22:01 AM EDT

# %% [markdown]
# ### QUESTION 5: (Using SparkSQL)
# What "yearmonth" has a highest PCP, and lowest PCP?

# %%
# %%file sparkSql.py

from pyspark.sql import SparkSession
from pyspark.sql import Row

import collections

spark = SparkSession.builder.config("spark.sql.warehouse.dir", "file:///C:/temp").appName("SparkSQL").getOrCreate()

def mapper(line):
    fields = line.split(',')
    return Row(sc=int(fields[0]), division=str(fields[1]), yearmonth=int(fields[2]), tavg=float(fields[3]),
               tmin=float(fields[4]), tmax=float(fields[5]), pcp=float(fields[6]), pdsi=float(fields[7]),
                phdi=float(fields[8]),zndx=float(fields[9]), pmdi=float(fields[10]), cdd=float(fields[11]),
              hdd=float(fields[12]), sp01=float(fields[13]), sp02=float(fields[14]), sp03=float(fields[15]),
              sp06=float(fields[16]), sp09=float(fields[17]),sp12=float(fields[18]), sp24=float(fields[19]))

lines = spark.sparkContext.textFile("TexasTempNone.csv")
x = lines.map(mapper)

schemaPcP = spark.createDataFrame(x).cache()
schemaPcP.createOrReplaceTempView("x")

pcps = spark.sql("SELECT yearmonth, pcp FROM x ORDER BY pcp DESC ")

for pcp in pcps.collect():
  print(pcp)


spark.stop()
# Out:
# Overwriting sparkSql.py

# %%
# !spark-submit sparkSql.py
# Out:
# 17/05/07 23:17:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Row(yearmonth=201505, pcp=9.05)
# Row(yearmonth=200406, pcp=6.66)
# Row(yearmonth=191405, pcp=6.62)
# Row(yearmonth=193609, pcp=6.55)
# Row(yearmonth=192905, pcp=6.45)
# Row(yearmonth=193505, pcp=6.38)
# Row(yearmonth=197409, pcp=6.32)
# Row(yearmonth=191910, pcp=6.26)
# Row(yearmonth=195704, pcp=6.19)
# Row(yearmonth=200411, pcp=6.18)
# Row(yearmonth=200210, pcp=6.17)
# Row(yearmonth=201510, pcp=6.17)
# Row(yearmonth=198410, pcp=5.95)
# Row(yearmonth=195809, pcp=5.86)
# Row(yearmonth=198110, pcp=5.86)
# Row(yearmonth=192106, pcp=5.82)
# Row(yearmonth=193010, pcp=5.79)
# Row(yearmonth=191408, pcp=5.69)
# Row(yearmonth=195705, pcp=5.69)
# Row(yearmonth=194110, pcp=5.68)
# Row(yearmonth=193605, pcp=5.64)
# Row(yearmonth=189906, pcp=5.6)
# Row(yearmonth=196709, pcp=5.6)
# Row(yearmonth=199112, pcp=5.59)
# Row(yearmonth=200910, pcp=5.55)
# Row(yearmonth=200705, pcp=5.54)
# Row(yearmonth=191309, pcp=5.53)
# Row(yearmonth=198009, pcp=5.51)
# Row(yearmonth=196106, pcp=5.5)
# Row(yearmonth=197408, pcp=5.49)
# Row(yearmonth=192204, pcp=5.48)
# Row(yearmonth=198705, pcp=5.47)
# Row(yearmonth=192008, pcp=5.46)
# Row(yearmonth=194105, pcp=5.45)
# Row(yearmonth=201608, pcp=5.45)
# Row(yearmonth=198205, pcp=5.38)
# Row(yearmonth=198610, pcp=5.38)
# Row(yearmonth=200707, pcp=5.37)
# Row(yearmonth=200706, pcp=5.33)
# Row(yearmonth=193209, pcp=5.31)
# Row(yearmonth=190004, pcp=5.27)
# Row(yearmonth=198106, pcp=5.26)
# Row(yearmonth=194106, pcp=5.25)
# Row(yearmonth=194405, pcp=5.25)
# Row(yearmonth=196505, pcp=5.24)
# Row(yearmonth=200011, pcp=5.24)
# Row(yearmonth=198706, pcp=5.23)
# Row(yearmonth=199608, pcp=5.23)
# Row(yearmonth=196010, pcp=5.22)
# Row(yearmonth=197309, pcp=5.19)
# Row(yearmonth=199810, pcp=5.18)
# Row(yearmonth=194011, pcp=5.17)
# Row(yearmonth=191504, pcp=5.14)
# Row(yearmonth=197108, pcp=5.14)
# Row(yearmonth=201007, pcp=5.12)
# Row(yearmonth=190009, pcp=5.1)
# Row(yearmonth=197505, pcp=5.1)
# Row(yearmonth=199205, pcp=5.09)
# Row(yearmonth=191906, pcp=5.05)
# Row(yearmonth=191909, pcp=5.04)
# Row(yearmonth=193509, pcp=5.04)
# Row(yearmonth=199410, pcp=5.04)
# Row(yearmonth=194910, pcp=5.03)
# Row(yearmonth=200006, pcp=5.03)
# Row(yearmonth=190504, pcp=4.97)
# Row(yearmonth=198606, pcp=4.97)
# Row(yearmonth=189505, pcp=4.96)
# Row(yearmonth=197306, pcp=4.96)
# Row(yearmonth=197607, pcp=4.96)
# Row(yearmonth=190710, pcp=4.95)
# Row(yearmonth=190207, pcp=4.94)
# Row(yearmonth=190705, pcp=4.93)
# Row(yearmonth=198906, pcp=4.93)
# Row(yearmonth=201605, pcp=4.92)
# Row(yearmonth=196608, pcp=4.91)
# Row(yearmonth=199704, pcp=4.91)
# Row(yearmonth=194006, pcp=4.87)
# Row(yearmonth=189806, pcp=4.86)
# Row(yearmonth=196409, pcp=4.85)
# Row(yearmonth=192310, pcp=4.8)
# Row(yearmonth=199109, pcp=4.8)
# Row(yearmonth=191508, pcp=4.78)
# Row(yearmonth=196604, pcp=4.76)
# Row(yearmonth=197109, pcp=4.76)
# Row(yearmonth=197009, pcp=4.74)
# Row(yearmonth=194204, pcp=4.73)
# Row(yearmonth=200207, pcp=4.73)
# Row(yearmonth=190805, pcp=4.72)
# Row(yearmonth=193506, pcp=4.68)
# Row(yearmonth=190211, pcp=4.67)
# Row(yearmonth=199505, pcp=4.67)
# Row(yearmonth=194705, pcp=4.64)
# Row(yearmonth=195710, pcp=4.64)
# Row(yearmonth=197310, pcp=4.63)
# Row(yearmonth=197809, pcp=4.6)
# Row(yearmonth=190607, pcp=4.56)
# Row(yearmonth=198510, pcp=4.55)
# Row(yearmonth=199706, pcp=4.55)
# Row(yearmonth=189609, pcp=4.54)
# Row(yearmonth=195910, pcp=4.54)
# Row(yearmonth=198005, pcp=4.53)
# Row(yearmonth=199405, pcp=4.52)
# Row(yearmonth=200808, pcp=4.52)
# Row(yearmonth=190007, pcp=4.49)
# Row(yearmonth=198605, pcp=4.49)
# Row(yearmonth=200306, pcp=4.48)
# Row(yearmonth=196805, pcp=4.47)
# Row(yearmonth=200703, pcp=4.47)
# Row(yearmonth=192005, pcp=4.42)
# Row(yearmonth=194208, pcp=4.38)
# Row(yearmonth=196206, pcp=4.38)
# Row(yearmonth=191905, pcp=4.36)
# Row(yearmonth=201604, pcp=4.36)
# Row(yearmonth=199306, pcp=4.34)
# Row(yearmonth=193005, pcp=4.33)
# Row(yearmonth=196209, pcp=4.33)
# Row(yearmonth=198105, pcp=4.33)
# Row(yearmonth=199206, pcp=4.31)
# Row(yearmonth=201009, pcp=4.31)
# Row(yearmonth=194605, pcp=4.3)
# Row(yearmonth=194109, pcp=4.29)
# Row(yearmonth=190005, pcp=4.24)
# Row(yearmonth=190406, pcp=4.24)
# Row(yearmonth=192312, pcp=4.24)
# Row(yearmonth=190804, pcp=4.22)
# Row(yearmonth=197610, pcp=4.22)
# Row(yearmonth=200909, pcp=4.2)
# Row(yearmonth=194104, pcp=4.19)
# Row(yearmonth=196905, pcp=4.18)
# Row(yearmonth=196910, pcp=4.16)
# Row(yearmonth=199007, pcp=4.16)
# Row(yearmonth=197609, pcp=4.14)
# Row(yearmonth=199106, pcp=4.14)
# Row(yearmonth=190711, pcp=4.11)
# Row(yearmonth=190409, pcp=4.1)
# Row(yearmonth=201405, pcp=4.1)
# Row(yearmonth=192309, pcp=4.09)
# Row(yearmonth=192603, pcp=4.09)
# Row(yearmonth=197604, pcp=4.09)
# Row(yearmonth=190302, pcp=4.08)
# Row(yearmonth=199609, pcp=4.08)
# Row(yearmonth=191112, pcp=4.05)
# Row(yearmonth=195906, pcp=4.05)
# Row(yearmonth=201309, pcp=4.05)
# Row(yearmonth=200610, pcp=4.03)
# Row(yearmonth=191104, pcp=4.02)
# Row(yearmonth=197205, pcp=4.02)
# Row(yearmonth=194904, pcp=4.0)
# Row(yearmonth=200010, pcp=4.0)
# Row(yearmonth=192706, pcp=3.99)
# Row(yearmonth=197410, pcp=3.99)
# Row(yearmonth=198509, pcp=3.99)
# Row(yearmonth=199202, pcp=3.98)
# Row(yearmonth=190306, pcp=3.96)
# Row(yearmonth=195007, pcp=3.96)
# Row(yearmonth=201504, pcp=3.96)
# Row(yearmonth=189506, pcp=3.95)
# Row(yearmonth=196007, pcp=3.95)
# Row(yearmonth=197110, pcp=3.95)
# Row(yearmonth=198905, pcp=3.95)
# Row(yearmonth=200410, pcp=3.95)
# Row(yearmonth=201209, pcp=3.95)
# Row(yearmonth=196806, pcp=3.94)
# Row(yearmonth=200404, pcp=3.94)
# Row(yearmonth=190405, pcp=3.91)
# Row(yearmonth=192510, pcp=3.91)
# Row(yearmonth=197704, pcp=3.91)
# Row(yearmonth=200309, pcp=3.91)
# Row(yearmonth=192509, pcp=3.89)
# Row(yearmonth=199906, pcp=3.89)
# Row(yearmonth=190307, pcp=3.88)
# Row(yearmonth=190505, pcp=3.88)
# Row(yearmonth=198609, pcp=3.88)
# Row(yearmonth=194408, pcp=3.87)
# Row(yearmonth=197905, pcp=3.87)
# Row(yearmonth=201511, pcp=3.87)
# Row(yearmonth=196012, pcp=3.86)
# Row(yearmonth=191907, pcp=3.85)
# Row(yearmonth=191306, pcp=3.84)
# Row(yearmonth=195009, pcp=3.84)
# Row(yearmonth=196107, pcp=3.83)
# Row(yearmonth=195005, pcp=3.81)
# Row(yearmonth=197307, pcp=3.81)
# Row(yearmonth=191312, pcp=3.8)
# Row(yearmonth=192610, pcp=3.79)
# Row(yearmonth=199702, pcp=3.79)
# Row(yearmonth=191107, pcp=3.77)
# Row(yearmonth=190507, pcp=3.76)
# Row(yearmonth=195405, pcp=3.75)
# Row(yearmonth=190503, pcp=3.74)
# Row(yearmonth=190608, pcp=3.74)
# Row(yearmonth=193201, pcp=3.74)
# Row(yearmonth=199009, pcp=3.73)
# Row(yearmonth=194305, pcp=3.72)
# Row(yearmonth=195907, pcp=3.72)
# Row(yearmonth=197907, pcp=3.72)
# Row(yearmonth=201506, pcp=3.72)
# Row(yearmonth=195711, pcp=3.71)
# Row(yearmonth=190209, pcp=3.69)
# Row(yearmonth=195505, pcp=3.69)
# Row(yearmonth=196006, pcp=3.69)
# Row(yearmonth=198206, pcp=3.69)
# Row(yearmonth=199808, pcp=3.69)
# Row(yearmonth=194609, pcp=3.68)
# Row(yearmonth=196801, pcp=3.66)
# Row(yearmonth=199509, pcp=3.66)
# Row(yearmonth=192302, pcp=3.65)
# Row(yearmonth=199905, pcp=3.65)
# Row(yearmonth=189610, pcp=3.64)
# Row(yearmonth=192205, pcp=3.64)
# Row(yearmonth=192304, pcp=3.63)
# Row(yearmonth=197209, pcp=3.63)
# Row(yearmonth=194209, pcp=3.62)
# Row(yearmonth=198305, pcp=3.62)
# Row(yearmonth=198506, pcp=3.62)
# Row(yearmonth=199105, pcp=3.62)
# Row(yearmonth=191311, pcp=3.6)
# Row(yearmonth=200108, pcp=3.6)
# Row(yearmonth=192405, pcp=3.59)
# Row(yearmonth=197507, pcp=3.59)
# Row(yearmonth=201409, pcp=3.59)
# Row(yearmonth=190205, pcp=3.58)
# Row(yearmonth=191310, pcp=3.58)
# Row(yearmonth=191811, pcp=3.58)
# Row(yearmonth=192607, pcp=3.58)
# Row(yearmonth=190506, pcp=3.56)
# Row(yearmonth=199004, pcp=3.56)
# Row(yearmonth=200701, pcp=3.55)
# Row(yearmonth=191509, pcp=3.54)
# Row(yearmonth=193208, pcp=3.54)
# Row(yearmonth=195905, pcp=3.54)
# Row(yearmonth=199101, pcp=3.53)
# Row(yearmonth=194901, pcp=3.52)
# Row(yearmonth=198809, pcp=3.52)
# Row(yearmonth=199705, pcp=3.52)
# Row(yearmonth=195310, pcp=3.49)
# Row(yearmonth=197208, pcp=3.49)
# Row(yearmonth=195205, pcp=3.48)
# Row(yearmonth=196609, pcp=3.48)
# Row(yearmonth=197906, pcp=3.48)
# Row(yearmonth=190807, pcp=3.47)
# Row(yearmonth=192806, pcp=3.47)
# Row(yearmonth=201503, pcp=3.47)
# Row(yearmonth=195709, pcp=3.46)
# Row(yearmonth=199305, pcp=3.46)
# Row(yearmonth=193112, pcp=3.45)
# Row(yearmonth=193712, pcp=3.45)
# Row(yearmonth=201606, pcp=3.45)
# Row(yearmonth=197304, pcp=3.44)
# Row(yearmonth=191404, pcp=3.43)
# Row(yearmonth=200508, pcp=3.42)
# Row(yearmonth=194611, pcp=3.41)
# Row(yearmonth=192612, pcp=3.4)
# Row(yearmonth=193307, pcp=3.4)
# Row(yearmonth=194107, pcp=3.4)
# Row(yearmonth=198310, pcp=3.4)
# Row(yearmonth=193607, pcp=3.39)
# Row(yearmonth=196008, pcp=3.39)
# Row(yearmonth=197605, pcp=3.39)
# Row(yearmonth=199809, pcp=3.39)
# Row(yearmonth=197005, pcp=3.38)
# Row(yearmonth=189507, pcp=3.37)
# Row(yearmonth=196109, pcp=3.37)
# Row(yearmonth=191810, pcp=3.36)
# Row(yearmonth=193807, pcp=3.36)
# Row(yearmonth=194507, pcp=3.36)
# Row(yearmonth=195105, pcp=3.36)
# Row(yearmonth=195109, pcp=3.36)
# Row(yearmonth=190609, pcp=3.35)
# Row(yearmonth=191410, pcp=3.35)
# Row(yearmonth=195204, pcp=3.35)
# Row(yearmonth=192604, pcp=3.34)
# Row(yearmonth=195308, pcp=3.33)
# Row(yearmonth=193305, pcp=3.32)
# Row(yearmonth=194906, pcp=3.32)
# Row(yearmonth=196809, pcp=3.32)
# Row(yearmonth=198807, pcp=3.32)
# Row(yearmonth=192805, pcp=3.31)
# Row(yearmonth=200111, pcp=3.31)
# Row(yearmonth=201310, pcp=3.31)
# Row(yearmonth=194510, pcp=3.3)
# Row(yearmonth=198612, pcp=3.3)
# Row(yearmonth=195211, pcp=3.29)
# Row(yearmonth=194005, pcp=3.27)
# Row(yearmonth=199710, pcp=3.27)
# Row(yearmonth=200609, pcp=3.27)
# Row(yearmonth=200103, pcp=3.25)
# Row(yearmonth=189705, pcp=3.23)
# Row(yearmonth=200109, pcp=3.23)
# Row(yearmonth=198108, pcp=3.22)
# Row(yearmonth=197210, pcp=3.21)
# Row(yearmonth=199005, pcp=3.2)
# Row(yearmonth=200904, pcp=3.2)
# Row(yearmonth=194210, pcp=3.19)
# Row(yearmonth=193212, pcp=3.18)
# Row(yearmonth=200408, pcp=3.18)
# Row(yearmonth=193411, pcp=3.16)
# Row(yearmonth=195305, pcp=3.16)
# Row(yearmonth=197811, pcp=3.16)
# Row(yearmonth=198702, pcp=3.16)
# Row(yearmonth=195106, pcp=3.15)
# Row(yearmonth=199201, pcp=3.15)
# Row(yearmonth=199811, pcp=3.15)
# Row(yearmonth=191005, pcp=3.14)
# Row(yearmonth=194309, pcp=3.14)
# Row(yearmonth=199003, pcp=3.14)
# Row(yearmonth=194905, pcp=3.13)
# Row(yearmonth=200005, pcp=3.13)
# Row(yearmonth=190707, pcp=3.11)
# Row(yearmonth=192001, pcp=3.11)
# Row(yearmonth=194601, pcp=3.11)
# Row(yearmonth=200212, pcp=3.11)
# Row(yearmonth=191206, pcp=3.1)
# Row(yearmonth=196811, pcp=3.1)
# Row(yearmonth=201307, pcp=3.1)
# Row(yearmonth=192006, pcp=3.09)
# Row(yearmonth=196807, pcp=3.09)
# Row(yearmonth=200907, pcp=3.09)
# Row(yearmonth=194503, pcp=3.08)
# Row(yearmonth=199107, pcp=3.08)
# Row(yearmonth=199211, pcp=3.08)
# Row(yearmonth=201203, pcp=3.07)
# Row(yearmonth=194411, pcp=3.06)
# Row(yearmonth=194805, pcp=3.06)
# Row(yearmonth=189907, pcp=3.05)
# Row(yearmonth=196509, pcp=3.05)
# Row(yearmonth=196605, pcp=3.05)
# Row(yearmonth=198211, pcp=3.05)
# Row(yearmonth=189508, pcp=3.04)
# Row(yearmonth=191604, pcp=3.04)
# Row(yearmonth=195706, pcp=3.04)
# Row(yearmonth=190109, pcp=3.03)
# Row(yearmonth=191411, pcp=3.03)
# Row(yearmonth=197805, pcp=3.03)
# Row(yearmonth=199108, pcp=3.03)
# Row(yearmonth=193806, pcp=3.02)
# Row(yearmonth=194012, pcp=3.02)
# Row(yearmonth=200105, pcp=3.02)
# Row(yearmonth=190010, pcp=3.01)
# Row(yearmonth=192605, pcp=3.01)
# Row(yearmonth=194401, pcp=3.01)
# Row(yearmonth=195810, pcp=3.01)
# Row(yearmonth=196904, pcp=3.01)
# Row(yearmonth=199310, pcp=3.01)
# Row(yearmonth=200507, pcp=3.01)
# Row(yearmonth=201406, pcp=3.01)
# Row(yearmonth=189706, pcp=3.0)
# Row(yearmonth=189708, pcp=3.0)
# Row(yearmonth=190511, pcp=3.0)
# Row(yearmonth=193308, pcp=3.0)
# Row(yearmonth=196909, pcp=3.0)
# Row(yearmonth=191908, pcp=2.99)
# Row(yearmonth=198608, pcp=2.99)
# Row(yearmonth=200209, pcp=2.99)
# Row(yearmonth=201609, pcp=2.99)
# Row(yearmonth=192206, pcp=2.98)
# Row(yearmonth=195509, pcp=2.98)
# Row(yearmonth=197904, pcp=2.98)
# Row(yearmonth=194412, pcp=2.97)
# Row(yearmonth=195006, pcp=2.97)
# Row(yearmonth=197806, pcp=2.97)
# Row(yearmonth=199506, pcp=2.97)
# Row(yearmonth=192010, pcp=2.96)
# Row(yearmonth=196705, pcp=2.96)
# Row(yearmonth=197908, pcp=2.96)
# Row(yearmonth=199606, pcp=2.96)
# Row(yearmonth=192109, pcp=2.95)
# Row(yearmonth=194206, pcp=2.95)
# Row(yearmonth=197506, pcp=2.95)
# Row(yearmonth=192807, pcp=2.94)
# Row(yearmonth=197405, pcp=2.94)
# Row(yearmonth=191804, pcp=2.93)
# Row(yearmonth=191812, pcp=2.93)
# Row(yearmonth=193206, pcp=2.93)
# Row(yearmonth=194008, pcp=2.93)
# Row(yearmonth=196305, pcp=2.93)
# Row(yearmonth=197303, pcp=2.93)
# Row(yearmonth=198611, pcp=2.93)
# Row(yearmonth=190906, pcp=2.92)
# Row(yearmonth=199104, pcp=2.92)
# Row(yearmonth=200708, pcp=2.92)
# Row(yearmonth=190808, pcp=2.91)
# Row(yearmonth=192606, pcp=2.91)
# Row(yearmonth=193202, pcp=2.91)
# Row(yearmonth=197206, pcp=2.91)
# Row(yearmonth=198412, pcp=2.91)
# Row(yearmonth=194610, pcp=2.9)
# Row(yearmonth=197903, pcp=2.9)
# Row(yearmonth=193205, pcp=2.89)
# Row(yearmonth=193901, pcp=2.89)
# Row(yearmonth=200505, pcp=2.89)
# Row(yearmonth=191608, pcp=2.88)
# Row(yearmonth=192306, pcp=2.88)
# Row(yearmonth=193401, pcp=2.88)
# Row(yearmonth=195801, pcp=2.88)
# Row(yearmonth=195805, pcp=2.88)
# Row(yearmonth=196502, pcp=2.88)
# Row(yearmonth=201205, pcp=2.88)
# Row(yearmonth=195703, pcp=2.87)
# Row(yearmonth=197808, pcp=2.87)
# Row(yearmonth=191605, pcp=2.86)
# Row(yearmonth=201112, pcp=2.86)
# Row(yearmonth=190003, pcp=2.85)
# Row(yearmonth=192203, pcp=2.85)
# Row(yearmonth=200809, pcp=2.85)
# Row(yearmonth=201603, pcp=2.85)
# Row(yearmonth=194504, pcp=2.84)
# Row(yearmonth=194608, pcp=2.84)
# Row(yearmonth=198306, pcp=2.84)
# Row(yearmonth=199712, pcp=2.84)
# Row(yearmonth=199903, pcp=2.84)
# Row(yearmonth=193804, pcp=2.83)
# Row(yearmonth=201411, pcp=2.83)
# Row(yearmonth=195404, pcp=2.82)
# Row(yearmonth=198709, pcp=2.82)
# Row(yearmonth=190105, pcp=2.81)
# Row(yearmonth=194506, pcp=2.81)
# Row(yearmonth=200402, pcp=2.81)
# Row(yearmonth=191412, pcp=2.8)
# Row(yearmonth=194508, pcp=2.8)
# Row(yearmonth=196306, pcp=2.8)
# Row(yearmonth=197112, pcp=2.8)
# Row(yearmonth=190008, pcp=2.79)
# Row(yearmonth=194103, pcp=2.79)
# Row(yearmonth=194207, pcp=2.79)
# Row(yearmonth=194606, pcp=2.79)
# Row(yearmonth=193905, pcp=2.78)
# Row(yearmonth=195410, pcp=2.78)
# Row(yearmonth=201006, pcp=2.78)
# Row(yearmonth=192707, pcp=2.77)
# Row(yearmonth=193107, pcp=2.77)
# Row(yearmonth=194307, pcp=2.76)
# Row(yearmonth=191903, pcp=2.75)
# Row(yearmonth=196506, pcp=2.75)
# Row(yearmonth=197010, pcp=2.75)
# Row(yearmonth=199412, pcp=2.75)
# Row(yearmonth=199508, pcp=2.75)
# Row(yearmonth=194909, pcp=2.74)
# Row(yearmonth=192909, pcp=2.73)
# Row(yearmonth=196804, pcp=2.73)
# Row(yearmonth=191102, pcp=2.72)
# Row(yearmonth=198212, pcp=2.72)
# Row(yearmonth=192104, pcp=2.71)
# Row(yearmonth=196111, pcp=2.71)
# Row(yearmonth=199611, pcp=2.71)
# Row(yearmonth=200310, pcp=2.71)
# Row(yearmonth=190905, pcp=2.7)
# Row(yearmonth=193403, pcp=2.7)
# Row(yearmonth=194004, pcp=2.7)
# Row(yearmonth=194108, pcp=2.7)
# Row(yearmonth=197909, pcp=2.7)
# Row(yearmonth=201207, pcp=2.7)
# Row(yearmonth=192409, pcp=2.69)
# Row(yearmonth=193906, pcp=2.69)
# Row(yearmonth=195912, pcp=2.69)
# Row(yearmonth=201004, pcp=2.69)
# Row(yearmonth=194409, pcp=2.68)
# Row(yearmonth=198505, pcp=2.68)
# Row(yearmonth=200709, pcp=2.68)
# Row(yearmonth=190605, pcp=2.67)
# Row(yearmonth=192709, pcp=2.67)
# Row(yearmonth=195004, pcp=2.67)
# Row(yearmonth=201501, pcp=2.67)
# Row(yearmonth=189912, pcp=2.66)
# Row(yearmonth=193404, pcp=2.65)
# Row(yearmonth=198104, pcp=2.65)
# Row(yearmonth=192505, pcp=2.64)
# Row(yearmonth=199802, pcp=2.64)
# Row(yearmonth=196908, pcp=2.63)
# Row(yearmonth=194907, pcp=2.62)
# Row(yearmonth=195806, pcp=2.62)
# Row(yearmonth=193102, pcp=2.61)
# Row(yearmonth=195904, pcp=2.61)
# Row(yearmonth=196707, pcp=2.61)
# Row(yearmonth=197411, pcp=2.61)
# Row(yearmonth=198503, pcp=2.61)
# Row(yearmonth=198712, pcp=2.61)
# Row(yearmonth=193805, pcp=2.6)
# Row(yearmonth=196204, pcp=2.6)
# Row(yearmonth=201002, pcp=2.59)
# Row(yearmonth=192809, pcp=2.58)
# Row(yearmonth=197003, pcp=2.58)
# Row(yearmonth=197301, pcp=2.58)
# Row(yearmonth=201407, pcp=2.58)
# Row(yearmonth=190604, pcp=2.55)
# Row(yearmonth=194509, pcp=2.55)
# Row(yearmonth=197509, pcp=2.55)
# Row(yearmonth=200106, pcp=2.55)
# Row(yearmonth=200409, pcp=2.55)
# Row(yearmonth=190107, pcp=2.54)
# Row(yearmonth=193710, pcp=2.54)
# Row(yearmonth=195508, pcp=2.54)
# Row(yearmonth=195804, pcp=2.54)
# Row(yearmonth=190512, pcp=2.53)
# Row(yearmonth=190809, pcp=2.53)
# Row(yearmonth=191607, pcp=2.53)
# Row(yearmonth=192710, pcp=2.53)
# Row(yearmonth=199002, pcp=2.53)
# Row(yearmonth=192808, pcp=2.52)
# Row(yearmonth=192910, pcp=2.52)
# Row(yearmonth=193512, pcp=2.52)
# Row(yearmonth=195807, pcp=2.52)
# Row(yearmonth=197706, pcp=2.52)
# Row(yearmonth=201512, pcp=2.52)
# Row(yearmonth=189703, pcp=2.51)
# Row(yearmonth=189910, pcp=2.51)
# Row(yearmonth=192311, pcp=2.51)
# Row(yearmonth=195605, pcp=2.51)
# Row(yearmonth=196408, pcp=2.51)
# Row(yearmonth=197107, pcp=2.51)
# Row(yearmonth=199607, pcp=2.51)
# Row(yearmonth=200502, pcp=2.51)
# Row(yearmonth=189511, pcp=2.5)
# Row(yearmonth=194102, pcp=2.5)
# Row(yearmonth=199409, pcp=2.5)
# Row(yearmonth=200612, pcp=2.5)
# Row(yearmonth=190407, pcp=2.49)
# Row(yearmonth=192911, pcp=2.49)
# Row(yearmonth=193104, pcp=2.49)
# Row(yearmonth=197508, pcp=2.49)
# Row(yearmonth=193801, pcp=2.48)
# Row(yearmonth=194312, pcp=2.48)
# Row(yearmonth=197207, pcp=2.48)
# Row(yearmonth=198711, pcp=2.48)
# Row(yearmonth=196311, pcp=2.47)
# Row(yearmonth=196512, pcp=2.47)
# Row(yearmonth=196903, pcp=2.47)
# Row(yearmonth=198406, pcp=2.47)
# Row(yearmonth=199504, pcp=2.47)
# Row(yearmonth=192601, pcp=2.46)
# Row(yearmonth=197901, pcp=2.46)
# Row(yearmonth=201301, pcp=2.46)
# Row(yearmonth=189808, pcp=2.45)
# Row(yearmonth=192007, pcp=2.45)
# Row(yearmonth=197606, pcp=2.45)
# Row(yearmonth=198806, pcp=2.45)
# Row(yearmonth=198908, pcp=2.45)
# Row(yearmonth=190509, pcp=2.44)
# Row(yearmonth=190606, pcp=2.44)
# Row(yearmonth=193101, pcp=2.44)
# Row(yearmonth=195507, pcp=2.44)
# Row(yearmonth=193706, pcp=2.43)
# Row(yearmonth=194708, pcp=2.43)
# Row(yearmonth=198511, pcp=2.43)
# Row(yearmonth=198708, pcp=2.43)
# Row(yearmonth=190907, pcp=2.42)
# Row(yearmonth=199207, pcp=2.42)
# Row(yearmonth=199303, pcp=2.42)
# Row(yearmonth=199703, pcp=2.42)
# Row(yearmonth=201305, pcp=2.42)
# Row(yearmonth=189510, pcp=2.41)
# Row(yearmonth=189807, pcp=2.41)
# Row(yearmonth=192704, pcp=2.41)
# Row(yearmonth=193011, pcp=2.41)
# Row(yearmonth=193105, pcp=2.41)
# Row(yearmonth=195506, pcp=2.41)
# Row(yearmonth=191204, pcp=2.4)
# Row(yearmonth=196101, pcp=2.4)
# Row(yearmonth=198008, pcp=2.4)
# Row(yearmonth=200302, pcp=2.4)
# Row(yearmonth=192303, pcp=2.39)
# Row(yearmonth=193705, pcp=2.39)
# Row(yearmonth=198107, pcp=2.39)
# Row(yearmonth=199304, pcp=2.39)
# Row(yearmonth=200206, pcp=2.39)
# Row(yearmonth=200405, pcp=2.39)
# Row(yearmonth=191904, pcp=2.38)
# Row(yearmonth=201611, pcp=2.38)
# Row(yearmonth=190410, pcp=2.37)
# Row(yearmonth=190911, pcp=2.37)
# Row(yearmonth=191212, pcp=2.37)
# Row(yearmonth=192903, pcp=2.37)
# Row(yearmonth=193703, pcp=2.37)
# Row(yearmonth=200407, pcp=2.37)
# Row(yearmonth=201001, pcp=2.37)
# Row(yearmonth=192907, pcp=2.36)
# Row(yearmonth=196606, pcp=2.36)
# Row(yearmonth=198504, pcp=2.36)
# Row(yearmonth=200003, pcp=2.36)
# Row(yearmonth=200307, pcp=2.36)
# Row(yearmonth=200608, pcp=2.36)
# Row(yearmonth=192508, pcp=2.35)
# Row(yearmonth=194402, pcp=2.35)
# Row(yearmonth=196405, pcp=2.35)
# Row(yearmonth=199803, pcp=2.35)
# Row(yearmonth=200101, pcp=2.35)
# Row(yearmonth=200403, pcp=2.35)
# Row(yearmonth=191901, pcp=2.34)
# Row(yearmonth=193907, pcp=2.34)
# Row(yearmonth=194205, pcp=2.34)
# Row(yearmonth=198901, pcp=2.34)
# Row(yearmonth=200803, pcp=2.34)
# Row(yearmonth=191208, pcp=2.33)
# Row(yearmonth=191507, pcp=2.33)
# Row(yearmonth=193908, pcp=2.33)
# Row(yearmonth=195908, pcp=2.33)
# Row(yearmonth=198109, pcp=2.33)
# Row(yearmonth=199110, pcp=2.33)
# Row(yearmonth=201306, pcp=2.33)
# Row(yearmonth=189805, pcp=2.32)
# Row(yearmonth=198303, pcp=2.32)
# Row(yearmonth=199708, pcp=2.32)
# Row(yearmonth=201701, pcp=2.32)
# Row(yearmonth=189911, pcp=2.31)
# Row(yearmonth=191705, pcp=2.31)
# Row(yearmonth=192608, pcp=2.31)
# Row(yearmonth=199011, pcp=2.31)
# Row(yearmonth=199204, pcp=2.31)
# Row(yearmonth=200607, pcp=2.31)
# Row(yearmonth=192011, pcp=2.3)
# Row(yearmonth=194902, pcp=2.3)
# Row(yearmonth=198302, pcp=2.3)
# Row(yearmonth=200905, pcp=2.3)
# Row(yearmonth=189905, pcp=2.29)
# Row(yearmonth=190305, pcp=2.29)
# Row(yearmonth=194306, pcp=2.29)
# Row(yearmonth=194711, pcp=2.29)
# Row(yearmonth=194806, pcp=2.29)
# Row(yearmonth=194908, pcp=2.29)
# Row(yearmonth=200805, pcp=2.29)
# Row(yearmonth=200807, pcp=2.29)
# Row(yearmonth=201202, pcp=2.29)
# Row(yearmonth=191210, pcp=2.28)
# Row(yearmonth=194010, pcp=2.28)
# Row(yearmonth=194712, pcp=2.28)
# Row(yearmonth=196912, pcp=2.28)
# Row(yearmonth=197705, pcp=2.28)
# Row(yearmonth=200112, pcp=2.28)
# Row(yearmonth=195802, pcp=2.27)
# Row(yearmonth=196210, pcp=2.27)
# Row(yearmonth=196902, pcp=2.27)
# Row(yearmonth=197106, pcp=2.27)
# Row(yearmonth=201005, pcp=2.27)
# Row(yearmonth=201201, pcp=2.27)
# Row(yearmonth=191506, pcp=2.26)
# Row(yearmonth=191805, pcp=2.26)
# Row(yearmonth=192107, pcp=2.26)
# Row(yearmonth=196803, pcp=2.26)
# Row(yearmonth=192811, pcp=2.25)
# Row(yearmonth=194701, pcp=2.25)
# Row(yearmonth=194807, pcp=2.25)
# Row(yearmonth=194912, pcp=2.25)
# Row(yearmonth=196710, pcp=2.25)
# Row(yearmonth=199212, pcp=2.25)
# Row(yearmonth=197708, pcp=2.24)
# Row(yearmonth=199203, pcp=2.24)
# Row(yearmonth=190001, pcp=2.23)
# Row(yearmonth=191806, pcp=2.23)
# Row(yearmonth=192308, pcp=2.23)
# Row(yearmonth=193006, pcp=2.23)
# Row(yearmonth=193207, pcp=2.23)
# Row(yearmonth=197302, pcp=2.23)
# Row(yearmonth=199001, pcp=2.23)
# Row(yearmonth=201110, pcp=2.23)
# Row(yearmonth=189601, pcp=2.22)
# Row(yearmonth=198103, pcp=2.22)
# Row(yearmonth=200912, pcp=2.22)
# Row(yearmonth=191203, pcp=2.21)
# Row(yearmonth=194502, pcp=2.21)
# Row(yearmonth=195304, pcp=2.21)
# Row(yearmonth=197105, pcp=2.21)
# Row(yearmonth=199503, pcp=2.21)
# Row(yearmonth=200903, pcp=2.21)
# Row(yearmonth=192211, pcp=2.2)
# Row(yearmonth=193309, pcp=2.2)
# Row(yearmonth=193409, pcp=2.2)
# Row(yearmonth=193507, pcp=2.2)
# Row(yearmonth=198405, pcp=2.2)
# Row(yearmonth=199010, pcp=2.2)
# Row(yearmonth=200605, pcp=2.2)
# Row(yearmonth=192009, pcp=2.19)
# Row(yearmonth=196704, pcp=2.19)
# Row(yearmonth=197002, pcp=2.19)
# Row(yearmonth=192103, pcp=2.18)
# Row(yearmonth=194802, pcp=2.18)
# Row(yearmonth=196207, pcp=2.18)
# Row(yearmonth=190610, pcp=2.17)
# Row(yearmonth=193110, pcp=2.17)
# Row(yearmonth=200401, pcp=2.17)
# Row(yearmonth=191004, pcp=2.16)
# Row(yearmonth=192609, pcp=2.16)
# Row(yearmonth=193610, pcp=2.16)
# Row(yearmonth=199301, pcp=2.16)
# Row(yearmonth=199801, pcp=2.16)
# Row(yearmonth=200810, pcp=2.16)
# Row(yearmonth=193103, pcp=2.15)
# Row(yearmonth=198507, pcp=2.15)
# Row(yearmonth=199709, pcp=2.15)
# Row(yearmonth=200510, pcp=2.15)
# Row(yearmonth=200704, pcp=2.15)
# Row(yearmonth=190908, pcp=2.14)
# Row(yearmonth=191305, pcp=2.14)
# Row(yearmonth=192507, pcp=2.14)
# Row(yearmonth=192511, pcp=2.14)
# Row(yearmonth=193510, pcp=2.14)
# Row(yearmonth=196102, pcp=2.14)
# Row(yearmonth=198308, pcp=2.14)
# Row(yearmonth=201612, pcp=2.14)
# Row(yearmonth=193204, pcp=2.13)
# Row(yearmonth=195008, pcp=2.13)
# Row(yearmonth=195207, pcp=2.13)
# Row(yearmonth=195902, pcp=2.13)
# Row(yearmonth=196708, pcp=2.13)
# Row(yearmonth=199008, pcp=2.13)
# Row(yearmonth=190308, pcp=2.12)
# Row(yearmonth=191505, pcp=2.12)
# Row(yearmonth=194604, pcp=2.12)
# Row(yearmonth=198909, pcp=2.12)
# Row(yearmonth=189710, pcp=2.11)
# Row(yearmonth=190303, pcp=2.11)
# Row(yearmonth=192802, pcp=2.11)
# Row(yearmonth=195307, pcp=2.11)
# Row(yearmonth=195808, pcp=2.11)
# Row(yearmonth=199507, pcp=2.11)
# Row(yearmonth=190806, pcp=2.1)
# Row(yearmonth=192712, pcp=2.1)
# Row(yearmonth=192812, pcp=2.1)
# Row(yearmonth=195212, pcp=2.1)
# Row(yearmonth=190309, pcp=2.09)
# Row(yearmonth=190502, pcp=2.09)
# Row(yearmonth=197502, pcp=2.09)
# Row(yearmonth=197912, pcp=2.09)
# Row(yearmonth=199309, pcp=2.09)
# Row(yearmonth=200308, pcp=2.09)
# Row(yearmonth=189904, pcp=2.08)
# Row(yearmonth=191601, pcp=2.08)
# Row(yearmonth=193504, pcp=2.08)
# Row(yearmonth=197504, pcp=2.08)
# Row(yearmonth=198411, pcp=2.08)
# Row(yearmonth=191610, pcp=2.07)
# Row(yearmonth=191911, pcp=2.07)
# Row(yearmonth=193708, pcp=2.07)
# Row(yearmonth=195702, pcp=2.07)
# Row(yearmonth=196309, pcp=2.07)
# Row(yearmonth=198011, pcp=2.07)
# Row(yearmonth=199408, pcp=2.07)
# Row(yearmonth=200603, pcp=2.07)
# Row(yearmonth=189602, pcp=2.06)
# Row(yearmonth=190210, pcp=2.06)
# Row(yearmonth=190408, pcp=2.06)
# Row(yearmonth=191108, pcp=2.06)
# Row(yearmonth=198309, pcp=2.06)
# Row(yearmonth=189604, pcp=2.05)
# Row(yearmonth=190006, pcp=2.05)
# Row(yearmonth=197211, pcp=2.05)
# Row(yearmonth=197703, pcp=2.05)
# Row(yearmonth=189804, pcp=2.04)
# Row(yearmonth=190404, pcp=2.04)
# Row(yearmonth=191406, pcp=2.04)
# Row(yearmonth=193106, pcp=2.04)
# Row(yearmonth=193111, pcp=2.04)
# Row(yearmonth=198409, pcp=2.04)
# Row(yearmonth=199907, pcp=2.04)
# Row(yearmonth=190510, pcp=2.03)
# Row(yearmonth=193108, pcp=2.03)
# Row(yearmonth=196411, pcp=2.03)
# Row(yearmonth=196508, pcp=2.03)
# Row(yearmonth=198707, pcp=2.03)
# Row(yearmonth=200102, pcp=2.03)
# Row(yearmonth=193709, pcp=2.02)
# Row(yearmonth=195002, pcp=2.02)
# Row(yearmonth=194002, pcp=2.01)
# Row(yearmonth=194706, pcp=2.01)
# Row(yearmonth=196808, pcp=2.01)
# Row(yearmonth=198204, pcp=2.0)
# Row(yearmonth=199407, pcp=2.0)
# Row(yearmonth=191707, pcp=1.99)
# Row(yearmonth=192703, pcp=1.99)
# Row(yearmonth=196706, pcp=1.99)
# Row(yearmonth=197401, pcp=1.99)
# Row(yearmonth=198408, pcp=1.99)
# Row(yearmonth=192404, pcp=1.98)
# Row(yearmonth=194703, pcp=1.98)
# Row(yearmonth=198307, pcp=1.98)
# Row(yearmonth=198502, pcp=1.98)
# Row(yearmonth=198805, pcp=1.98)
# Row(yearmonth=199208, pcp=1.98)
# Row(yearmonth=200203, pcp=1.98)
# Row(yearmonth=192105, pcp=1.97)
# Row(yearmonth=192904, pcp=1.97)
# Row(yearmonth=194403, pcp=1.97)
# Row(yearmonth=191205, pcp=1.96)
# Row(yearmonth=193911, pcp=1.96)
# Row(yearmonth=199404, pcp=1.96)
# Row(yearmonth=200606, pcp=1.96)
# Row(yearmonth=192402, pcp=1.95)
# Row(yearmonth=196510, pcp=1.95)
# Row(yearmonth=197612, pcp=1.95)
# Row(yearmonth=199904, pcp=1.95)
# Row(yearmonth=192403, pcp=1.94)
# Row(yearmonth=192504, pcp=1.94)
# Row(yearmonth=194406, pcp=1.94)
# Row(yearmonth=196001, pcp=1.94)
# Row(yearmonth=197406, pcp=1.94)
# Row(yearmonth=201311, pcp=1.94)
# Row(yearmonth=189704, pcp=1.93)
# Row(yearmonth=194704, pcp=1.93)
# Row(yearmonth=200806, pcp=1.93)
# Row(yearmonth=190811, pcp=1.92)
# Row(yearmonth=191809, pcp=1.92)
# Row(yearmonth=193502, pcp=1.92)
# Row(yearmonth=198311, pcp=1.92)
# Row(yearmonth=191105, pcp=1.91)
# Row(yearmonth=191304, pcp=1.91)
# Row(yearmonth=196009, pcp=1.91)
# Row(yearmonth=197711, pcp=1.91)
# Row(yearmonth=199302, pcp=1.91)
# Row(yearmonth=199406, pcp=1.91)
# Row(yearmonth=200004, pcp=1.91)
# Row(yearmonth=189502, pcp=1.9)
# Row(yearmonth=190301, pcp=1.9)
# Row(yearmonth=190910, pcp=1.9)
# Row(yearmonth=191708, pcp=1.9)
# Row(yearmonth=198902, pcp=1.9)
# Row(yearmonth=200205, pcp=1.9)
# Row(yearmonth=193802, pcp=1.89)
# Row(yearmonth=200501, pcp=1.89)
# Row(yearmonth=190611, pcp=1.88)
# Row(yearmonth=191709, pcp=1.88)
# Row(yearmonth=196602, pcp=1.88)
# Row(yearmonth=193405, pcp=1.87)
# Row(yearmonth=200804, pcp=1.87)
# Row(yearmonth=200906, pcp=1.87)
# Row(yearmonth=201003, pcp=1.87)
# Row(yearmonth=190704, pcp=1.86)
# Row(yearmonth=190706, pcp=1.86)
# Row(yearmonth=190912, pcp=1.86)
# Row(yearmonth=194212, pcp=1.86)
# Row(yearmonth=195103, pcp=1.86)
# Row(yearmonth=195209, pcp=1.86)
# Row(yearmonth=198903, pcp=1.86)
# Row(yearmonth=199209, pcp=1.86)
# Row(yearmonth=201206, pcp=1.86)
# Row(yearmonth=189812, pcp=1.85)
# Row(yearmonth=191403, pcp=1.85)
# Row(yearmonth=193803, pcp=1.85)
# Row(yearmonth=195803, pcp=1.85)
# Row(yearmonth=195909, pcp=1.85)
# Row(yearmonth=196712, pcp=1.85)
# Row(yearmonth=201507, pcp=1.85)
# Row(yearmonth=189709, pcp=1.84)
# Row(yearmonth=190802, pcp=1.84)
# Row(yearmonth=191103, pcp=1.84)
# Row(yearmonth=191407, pcp=1.84)
# Row(yearmonth=196406, pcp=1.84)
# Row(yearmonth=198210, pcp=1.84)
# Row(yearmonth=201208, pcp=1.84)
# Row(yearmonth=196002, pcp=1.83)
# Row(yearmonth=196304, pcp=1.83)
# Row(yearmonth=196911, pcp=1.83)
# Row(yearmonth=197308, pcp=1.83)
# Row(yearmonth=200211, pcp=1.83)
# Row(yearmonth=189909, pcp=1.82)
# Row(yearmonth=191606, pcp=1.82)
# Row(yearmonth=194603, pcp=1.82)
# Row(yearmonth=191609, pcp=1.81)
# Row(yearmonth=193707, pcp=1.81)
# Row(yearmonth=196211, pcp=1.81)
# Row(yearmonth=196906, pcp=1.81)
# Row(yearmonth=197008, pcp=1.81)
# Row(yearmonth=199711, pcp=1.81)
# Row(yearmonth=192201, pcp=1.8)
# Row(yearmonth=192207, pcp=1.8)
# Row(yearmonth=192810, pcp=1.8)
# Row(yearmonth=197004, pcp=1.8)
# Row(yearmonth=199411, pcp=1.8)
# Row(yearmonth=200503, pcp=1.8)
# Row(yearmonth=191006, pcp=1.79)
# Row(yearmonth=191202, pcp=1.79)
# Row(yearmonth=200204, pcp=1.79)
# Row(yearmonth=193302, pcp=1.78)
# Row(yearmonth=197006, pcp=1.78)
# Row(yearmonth=197404, pcp=1.78)
# Row(yearmonth=195502, pcp=1.77)
# Row(yearmonth=199403, pcp=1.77)
# Row(yearmonth=201304, pcp=1.77)
# Row(yearmonth=192804, pcp=1.76)
# Row(yearmonth=193701, pcp=1.76)
# Row(yearmonth=194007, pcp=1.76)
# Row(yearmonth=194404, pcp=1.76)
# Row(yearmonth=197902, pcp=1.76)
# Row(yearmonth=201410, pcp=1.76)
# Row(yearmonth=189809, pcp=1.75)
# Row(yearmonth=194311, pcp=1.75)
# Row(yearmonth=200012, pcp=1.75)
# Row(yearmonth=200208, pcp=1.75)
# Row(yearmonth=191502, pcp=1.74)
# Row(yearmonth=197802, pcp=1.74)
# Row(yearmonth=198604, pcp=1.74)
# Row(yearmonth=200110, pcp=1.74)
# Row(yearmonth=191302, pcp=1.73)
# Row(yearmonth=191704, pcp=1.73)
# Row(yearmonth=193004, pcp=1.73)
# Row(yearmonth=193711, pcp=1.73)
# Row(yearmonth=194809, pcp=1.73)
# Row(yearmonth=195406, pcp=1.73)
# Row(yearmonth=198207, pcp=1.73)
# Row(yearmonth=198907, pcp=1.73)
# Row(yearmonth=201408, pcp=1.73)
# Row(yearmonth=189607, pcp=1.72)
# Row(yearmonth=192209, pcp=1.72)
# Row(yearmonth=192210, pcp=1.72)
# Row(yearmonth=193511, pcp=1.72)
# Row(yearmonth=194501, pcp=1.72)
# Row(yearmonth=194602, pcp=1.72)
# Row(yearmonth=194612, pcp=1.72)
# Row(yearmonth=196403, pcp=1.72)
# Row(yearmonth=199610, pcp=1.72)
# Row(yearmonth=199812, pcp=1.72)
# Row(yearmonth=199901, pcp=1.72)
# Row(yearmonth=189701, pcp=1.71)
# Row(yearmonth=191110, pcp=1.71)
# Row(yearmonth=189712, pcp=1.7)
# Row(yearmonth=190310, pcp=1.7)
# Row(yearmonth=194303, pcp=1.7)
# Row(yearmonth=192702, pcp=1.69)
# Row(yearmonth=194903, pcp=1.69)
# Row(yearmonth=198202, pcp=1.69)
# Row(yearmonth=196105, pcp=1.68)
# Row(yearmonth=196601, pcp=1.68)
# Row(yearmonth=197305, pcp=1.68)
# Row(yearmonth=192406, pcp=1.67)
# Row(yearmonth=196103, pcp=1.67)
# Row(yearmonth=196404, pcp=1.67)
# Row(yearmonth=198001, pcp=1.67)
# Row(yearmonth=198407, pcp=1.67)
# Row(yearmonth=198803, pcp=1.67)
# Row(yearmonth=193012, pcp=1.66)
# Row(yearmonth=195303, pcp=1.66)
# Row(yearmonth=195312, pcp=1.66)
# Row(yearmonth=198808, pcp=1.66)
# Row(yearmonth=192305, pcp=1.65)
# Row(yearmonth=192901, pcp=1.65)
# Row(yearmonth=194407, pcp=1.65)
# Row(yearmonth=196308, pcp=1.65)
# Row(yearmonth=197412, pcp=1.65)
# Row(yearmonth=197801, pcp=1.65)
# Row(yearmonth=199102, pcp=1.65)
# Row(yearmonth=191209, pcp=1.64)
# Row(yearmonth=193009, pcp=1.64)
# Row(yearmonth=193606, pcp=1.64)
# Row(yearmonth=195610, pcp=1.64)
# Row(yearmonth=196802, pcp=1.64)
# Row(yearmonth=193612, pcp=1.63)
# Row(yearmonth=193407, pcp=1.62)
# Row(yearmonth=196212, pcp=1.62)
# Row(yearmonth=200908, pcp=1.62)
# Row(yearmonth=191012, pcp=1.61)
# Row(yearmonth=191501, pcp=1.61)
# Row(yearmonth=194804, pcp=1.61)
# Row(yearmonth=196307, pcp=1.61)
# Row(yearmonth=199308, pcp=1.61)
# Row(yearmonth=199501, pcp=1.61)
# Row(yearmonth=189801, pcp=1.6)
# Row(yearmonth=193508, pcp=1.6)
# Row(yearmonth=197510, pcp=1.6)
# Row(yearmonth=190612, pcp=1.59)
# Row(yearmonth=191009, pcp=1.59)
# Row(yearmonth=192408, pcp=1.59)
# Row(yearmonth=196108, pcp=1.59)
# Row(yearmonth=196401, pcp=1.59)
# Row(yearmonth=196511, pcp=1.59)
# Row(yearmonth=197701, pcp=1.59)
# Row(yearmonth=198602, pcp=1.59)
# Row(yearmonth=197603, pcp=1.58)
# Row(yearmonth=189803, pcp=1.57)
# Row(yearmonth=191010, pcp=1.57)
# Row(yearmonth=196110, pcp=1.57)
# Row(yearmonth=199512, pcp=1.57)
# Row(yearmonth=199909, pcp=1.57)
# Row(yearmonth=191503, pcp=1.56)
# Row(yearmonth=192307, pcp=1.56)
# Row(yearmonth=195202, pcp=1.56)
# Row(yearmonth=197710, pcp=1.56)
# Row(yearmonth=200311, pcp=1.56)
# Row(yearmonth=201105, pcp=1.56)
# Row(yearmonth=195602, pcp=1.55)
# Row(yearmonth=201101, pcp=1.55)
# Row(yearmonth=191109, pcp=1.54)
# Row(yearmonth=193303, pcp=1.54)
# Row(yearmonth=193902, pcp=1.54)
# Row(yearmonth=194101, pcp=1.54)
# Row(yearmonth=194808, pcp=1.54)
# Row(yearmonth=190206, pcp=1.53)
# Row(yearmonth=190212, pcp=1.53)
# Row(yearmonth=196004, pcp=1.53)
# Row(yearmonth=196402, pcp=1.53)
# Row(yearmonth=198403, pcp=1.53)
# Row(yearmonth=190204, pcp=1.52)
# Row(yearmonth=191808, pcp=1.52)
# Row(yearmonth=191902, pcp=1.52)
# Row(yearmonth=193001, pcp=1.52)
# Row(yearmonth=193312, pcp=1.52)
# Row(yearmonth=196011, pcp=1.52)
# Row(yearmonth=189512, pcp=1.51)
# Row(yearmonth=190412, pcp=1.51)
# Row(yearmonth=196005, pcp=1.51)
# Row(yearmonth=198003, pcp=1.51)
# Row(yearmonth=198301, pcp=1.51)
# Row(yearmonth=199402, pcp=1.51)
# Row(yearmonth=199604, pcp=1.51)
# Row(yearmonth=200604, pcp=1.51)
# Row(yearmonth=190708, pcp=1.5)
# Row(yearmonth=193503, pcp=1.5)
# Row(yearmonth=199111, pcp=1.5)
# Row(yearmonth=199511, pcp=1.5)
# Row(yearmonth=200305, pcp=1.5)
# Row(yearmonth=191512, pcp=1.49)
# Row(yearmonth=196501, pcp=1.49)
# Row(yearmonth=196610, pcp=1.49)
# Row(yearmonth=197104, pcp=1.49)
# Row(yearmonth=197611, pcp=1.49)
# Row(yearmonth=198401, pcp=1.49)
# Row(yearmonth=198501, pcp=1.49)
# Row(yearmonth=189811, pcp=1.48)
# Row(yearmonth=190104, pcp=1.48)
# Row(yearmonth=191303, pcp=1.48)
# Row(yearmonth=192301, pcp=1.48)
# Row(yearmonth=193003, pcp=1.48)
# Row(yearmonth=193301, pcp=1.48)
# Row(yearmonth=193412, pcp=1.48)
# Row(yearmonth=193604, pcp=1.48)
# Row(yearmonth=195001, pcp=1.48)
# Row(yearmonth=195501, pcp=1.48)
# Row(yearmonth=197204, pcp=1.48)
# Row(yearmonth=197709, pcp=1.48)
# Row(yearmonth=198804, pcp=1.48)
# Row(yearmonth=199401, pcp=1.48)
# Row(yearmonth=192906, pcp=1.46)
# Row(yearmonth=193912, pcp=1.46)
# Row(yearmonth=197608, pcp=1.46)
# Row(yearmonth=193910, pcp=1.45)
# Row(yearmonth=194112, pcp=1.45)
# Row(yearmonth=195504, pcp=1.45)
# Row(yearmonth=199312, pcp=1.45)
# Row(yearmonth=190108, pcp=1.44)
# Row(yearmonth=193812, pcp=1.44)
# Row(yearmonth=196810, pcp=1.44)
# Row(yearmonth=197403, pcp=1.44)
# Row(yearmonth=189707, pcp=1.43)
# Row(yearmonth=190102, pcp=1.43)
# Row(yearmonth=190110, pcp=1.43)
# Row(yearmonth=190712, pcp=1.43)
# Row(yearmonth=192705, pcp=1.43)
# Row(yearmonth=193809, pcp=1.43)
# Row(yearmonth=195408, pcp=1.43)
# Row(yearmonth=196711, pcp=1.43)
# Row(yearmonth=201508, pcp=1.43)
# Row(yearmonth=201509, pcp=1.43)
# Row(yearmonth=191007, pcp=1.42)
# Row(yearmonth=193008, pcp=1.42)
# Row(yearmonth=195203, pcp=1.42)
# Row(yearmonth=192912, pcp=1.41)
# Row(yearmonth=195612, pcp=1.41)
# Row(yearmonth=198004, pcp=1.41)
# Row(yearmonth=198910, pcp=1.41)
# Row(yearmonth=200509, pcp=1.41)
# Row(yearmonth=201308, pcp=1.41)
# Row(yearmonth=192101, pcp=1.4)
# Row(yearmonth=195107, pcp=1.4)
# Row(yearmonth=197201, pcp=1.4)
# Row(yearmonth=189504, pcp=1.38)
# Row(yearmonth=190602, pcp=1.38)
# Row(yearmonth=194811, pcp=1.38)
# Row(yearmonth=190810, pcp=1.37)
# Row(yearmonth=191207, pcp=1.37)
# Row(yearmonth=194810, pcp=1.37)
# Row(yearmonth=196112, pcp=1.37)
# Row(yearmonth=197511, pcp=1.37)
# Row(yearmonth=198812, pcp=1.37)
# Row(yearmonth=199707, pcp=1.37)
# Row(yearmonth=190203, pcp=1.36)
# Row(yearmonth=191510, pcp=1.36)
# Row(yearmonth=192102, pcp=1.36)
# Row(yearmonth=201312, pcp=1.36)
# Row(yearmonth=194505, pcp=1.35)
# Row(yearmonth=199908, pcp=1.35)
# Row(yearmonth=189612, pcp=1.34)
# Row(yearmonth=192412, pcp=1.34)
# Row(yearmonth=196907, pcp=1.34)
# Row(yearmonth=197807, pcp=1.34)
# Row(yearmonth=198703, pcp=1.34)
# Row(yearmonth=199605, pcp=1.34)
# Row(yearmonth=199910, pcp=1.34)
# Row(yearmonth=200711, pcp=1.34)
# Row(yearmonth=193608, pcp=1.33)
# Row(yearmonth=194512, pcp=1.33)
# Row(yearmonth=191111, pcp=1.32)
# Row(yearmonth=191308, pcp=1.32)
# Row(yearmonth=190111, pcp=1.31)
# Row(yearmonth=193408, pcp=1.31)
# Row(yearmonth=195604, pcp=1.31)
# Row(yearmonth=196607, pcp=1.31)
# Row(yearmonth=201607, pcp=1.31)
# Row(yearmonth=189501, pcp=1.3)
# Row(yearmonth=189901, pcp=1.3)
# Row(yearmonth=191008, pcp=1.3)
# Row(yearmonth=191307, pcp=1.3)
# Row(yearmonth=191409, pcp=1.3)
# Row(yearmonth=193402, pcp=1.3)
# Row(yearmonth=195102, pcp=1.3)
# Row(yearmonth=195309, pcp=1.3)
# Row(yearmonth=197111, pcp=1.3)
# Row(yearmonth=197702, pcp=1.3)
# Row(yearmonth=190508, pcp=1.29)
# Row(yearmonth=192202, pcp=1.29)
# Row(yearmonth=195510, pcp=1.29)
# Row(yearmonth=196812, pcp=1.29)
# Row(yearmonth=189802, pcp=1.28)
# Row(yearmonth=190709, pcp=1.28)
# Row(yearmonth=196312, pcp=1.28)
# Row(yearmonth=198006, pcp=1.28)
# Row(yearmonth=199307, pcp=1.28)
# Row(yearmonth=201008, pcp=1.28)
# Row(yearmonth=201111, pcp=1.28)
# Row(yearmonth=191611, pcp=1.27)
# Row(yearmonth=193904, pcp=1.27)
# Row(yearmonth=195302, pcp=1.27)
# Row(yearmonth=201204, pcp=1.27)
# Row(yearmonth=190603, pcp=1.26)
# Row(yearmonth=198402, pcp=1.26)
# Row(yearmonth=200911, pcp=1.26)
# Row(yearmonth=191301, pcp=1.25)
# Row(yearmonth=195110, pcp=1.25)
# Row(yearmonth=195708, pcp=1.25)
# Row(yearmonth=196504, pcp=1.25)
# Row(yearmonth=197812, pcp=1.25)
# Row(yearmonth=198209, pcp=1.25)
# Row(yearmonth=199311, pcp=1.25)
# Row(yearmonth=190803, pcp=1.24)
# Row(yearmonth=191003, pcp=1.24)
# Row(yearmonth=192401, pcp=1.24)
# Row(yearmonth=194607, pcp=1.24)
# Row(yearmonth=197707, pcp=1.24)
# Row(yearmonth=198208, pcp=1.24)
# Row(yearmonth=199701, pcp=1.24)
# Row(yearmonth=200506, pcp=1.24)
# Row(yearmonth=192506, pcp=1.23)
# Row(yearmonth=193501, pcp=1.23)
# Row(yearmonth=193811, pcp=1.23)
# Row(yearmonth=193203, pcp=1.22)
# Row(yearmonth=193611, pcp=1.22)
# Row(yearmonth=194009, pcp=1.22)
# Row(yearmonth=200712, pcp=1.22)
# Row(yearmonth=201412, pcp=1.22)
# Row(yearmonth=194801, pcp=1.21)
# Row(yearmonth=195811, pcp=1.21)
# Row(yearmonth=197512, pcp=1.21)
# Row(yearmonth=201302, pcp=1.21)
# Row(yearmonth=196412, pcp=1.2)
# Row(yearmonth=197407, pcp=1.2)
# Row(yearmonth=197910, pcp=1.2)
# Row(yearmonth=198607, pcp=1.2)
# Row(yearmonth=199807, pcp=1.2)
# Row(yearmonth=199912, pcp=1.2)
# Row(yearmonth=191402, pcp=1.19)
# Row(yearmonth=194410, pcp=1.19)
# Row(yearmonth=195911, pcp=1.19)
# Row(yearmonth=196208, pcp=1.19)
# Row(yearmonth=192208, pcp=1.18)
# Row(yearmonth=192407, pcp=1.18)
# Row(yearmonth=192902, pcp=1.18)
# Row(yearmonth=193002, pcp=1.18)
# Row(yearmonth=197501, pcp=1.18)
# Row(yearmonth=198010, pcp=1.18)
# Row(yearmonth=198101, pcp=1.18)
# Row(yearmonth=199006, pcp=1.18)
# Row(yearmonth=200009, pcp=1.18)
# Row(yearmonth=190501, pcp=1.17)
# Row(yearmonth=190904, pcp=1.17)
# Row(yearmonth=193310, pcp=1.17)
# Row(yearmonth=193808, pcp=1.17)
# Row(yearmonth=195606, pcp=1.17)
# Row(yearmonth=197810, pcp=1.17)
# Row(yearmonth=198810, pcp=1.17)
# Row(yearmonth=190011, pcp=1.16)
# Row(yearmonth=192611, pcp=1.16)
# Row(yearmonth=193304, pcp=1.16)
# Row(yearmonth=195601, pcp=1.16)
# Row(yearmonth=196302, pcp=1.16)
# Row(yearmonth=198111, pcp=1.16)
# Row(yearmonth=189608, pcp=1.15)
# Row(yearmonth=197102, pcp=1.15)
# Row(yearmonth=198701, pcp=1.15)
# Row(yearmonth=200710, pcp=1.15)
# Row(yearmonth=192501, pcp=1.14)
# Row(yearmonth=195611, pcp=1.14)
# Row(yearmonth=196503, pcp=1.14)
# Row(yearmonth=199510, pcp=1.14)
# Row(yearmonth=199806, pcp=1.14)
# Row(yearmonth=200602, pcp=1.14)
# Row(yearmonth=201109, pcp=1.14)
# Row(yearmonth=196205, pcp=1.13)
# Row(yearmonth=198904, pcp=1.13)
# Row(yearmonth=200303, pcp=1.13)
# Row(yearmonth=192108, pcp=1.12)
# Row(yearmonth=195108, pcp=1.12)
# Row(yearmonth=195411, pcp=1.12)
# Row(yearmonth=192012, pcp=1.11)
# Row(yearmonth=194304, pcp=1.11)
# Row(yearmonth=194310, pcp=1.11)
# Row(yearmonth=195206, pcp=1.11)
# Row(yearmonth=198012, pcp=1.11)
# Row(yearmonth=201403, pcp=1.11)
# Row(yearmonth=198102, pcp=1.1)
# Row(yearmonth=198203, pcp=1.1)
# Row(yearmonth=200802, pcp=1.1)
# Row(yearmonth=189606, pcp=1.09)
# Row(yearmonth=191803, pcp=1.09)
# Row(yearmonth=192708, pcp=1.09)
# Row(yearmonth=197311, pcp=1.09)
# Row(yearmonth=198312, pcp=1.09)
# Row(yearmonth=201502, pcp=1.09)
# Row(yearmonth=191211, pcp=1.08)
# Row(yearmonth=194803, pcp=1.08)
# Row(yearmonth=192112, pcp=1.07)
# Row(yearmonth=195608, pcp=1.07)
# Row(yearmonth=196407, pcp=1.07)
# Row(yearmonth=197804, pcp=1.07)
# Row(yearmonth=199012, pcp=1.07)
# Row(yearmonth=201602, pcp=1.07)
# Row(yearmonth=191807, pcp=1.06)
# Row(yearmonth=194710, pcp=1.06)
# Row(yearmonth=197007, pcp=1.06)
# Row(yearmonth=197503, pcp=1.06)
# Row(yearmonth=200601, pcp=1.06)
# Row(yearmonth=195311, pcp=1.05)
# Row(yearmonth=195607, pcp=1.05)
# Row(yearmonth=199612, pcp=1.05)
# Row(yearmonth=200001, pcp=1.05)
# Row(yearmonth=200202, pcp=1.05)
# Row(yearmonth=190402, pcp=1.04)
# Row(yearmonth=195104, pcp=1.04)
# Row(yearmonth=195306, pcp=1.04)
# Row(yearmonth=198002, pcp=1.04)
# Row(yearmonth=198508, pcp=1.04)
# Row(yearmonth=201011, pcp=1.04)
# Row(yearmonth=190703, pcp=1.03)
# Row(yearmonth=189810, pcp=1.02)
# Row(yearmonth=191002, pcp=1.02)
# Row(yearmonth=192003, pcp=1.02)
# Row(yearmonth=194301, pcp=1.02)
# Row(yearmonth=199502, pcp=1.02)
# Row(yearmonth=195407, pcp=1.01)
# Row(yearmonth=196003, pcp=1.01)
# Row(yearmonth=199103, pcp=1.01)
# Row(yearmonth=200002, pcp=1.01)
# Row(yearmonth=190002, pcp=1.0)
# Row(yearmonth=192803, pcp=1.0)
# Row(yearmonth=196703, pcp=1.0)
# Row(yearmonth=190903, pcp=0.99)
# Row(yearmonth=190909, pcp=0.99)
# Row(yearmonth=193603, pcp=0.99)
# Row(yearmonth=194202, pcp=0.99)
# Row(yearmonth=194709, pcp=0.99)
# Row(yearmonth=195707, pcp=0.99)
# Row(yearmonth=198201, pcp=0.99)
# Row(yearmonth=198512, pcp=0.99)
# Row(yearmonth=200811, pcp=0.99)
# Row(yearmonth=192701, pcp=0.98)
# Row(yearmonth=193007, pcp=0.98)
# Row(yearmonth=194111, pcp=0.98)
# Row(yearmonth=201106, pcp=0.98)
# Row(yearmonth=201404, pcp=0.98)
# Row(yearmonth=196201, pcp=0.97)
# Row(yearmonth=200107, pcp=0.97)
# Row(yearmonth=201212, pcp=0.97)
# Row(yearmonth=190103, pcp=0.96)
# Row(yearmonth=195401, pcp=0.96)
# Row(yearmonth=200201, pcp=0.96)
# Row(yearmonth=201601, pcp=0.96)
# Row(yearmonth=193311, pcp=0.95)
# Row(yearmonth=194707, pcp=0.95)
# Row(yearmonth=195101, pcp=0.95)
# Row(yearmonth=195712, pcp=0.95)
# Row(yearmonth=190304, pcp=0.94)
# Row(yearmonth=193909, pcp=0.94)
# Row(yearmonth=200801, pcp=0.94)
# Row(yearmonth=190106, pcp=0.93)
# Row(yearmonth=195409, pcp=0.93)
# Row(yearmonth=197312, pcp=0.93)
# Row(yearmonth=199210, pcp=0.93)
# Row(yearmonth=194203, pcp=0.92)
# Row(yearmonth=195701, pcp=0.92)
# Row(yearmonth=190701, pcp=0.91)
# Row(yearmonth=194003, pcp=0.91)
# Row(yearmonth=194211, pcp=0.91)
# Row(yearmonth=196410, pcp=0.91)
# Row(yearmonth=193704, pcp=0.9)
# Row(yearmonth=198704, pcp=0.9)
# Row(yearmonth=193810, pcp=0.89)
# Row(yearmonth=196310, pcp=0.89)
# Row(yearmonth=198811, pcp=0.89)
# Row(yearmonth=189503, pcp=0.88)
# Row(yearmonth=190112, pcp=0.88)
# Row(yearmonth=190801, pcp=0.88)
# Row(yearmonth=193406, pcp=0.88)
# Row(yearmonth=193903, pcp=0.88)
# Row(yearmonth=189611, pcp=0.87)
# Row(yearmonth=192004, pcp=0.87)
# Row(yearmonth=197911, pcp=0.87)
# Row(yearmonth=190601, pcp=0.86)
# Row(yearmonth=195111, pcp=0.86)
# Row(yearmonth=198802, pcp=0.86)
# Row(yearmonth=190012, pcp=0.85)
# Row(yearmonth=190702, pcp=0.85)
# Row(yearmonth=192908, pcp=0.85)
# Row(yearmonth=196203, pcp=0.85)
# Row(yearmonth=196507, pcp=0.85)
# Row(yearmonth=191912, pcp=0.84)
# Row(yearmonth=192512, pcp=0.84)
# Row(yearmonth=195812, pcp=0.84)
# Row(yearmonth=197001, pcp=0.84)
# Row(yearmonth=197803, pcp=0.84)
# Row(yearmonth=189603, pcp=0.83)
# Row(yearmonth=190312, pcp=0.83)
# Row(yearmonth=191701, pcp=0.83)
# Row(yearmonth=197203, pcp=0.83)
# Row(yearmonth=197212, pcp=0.83)
# Row(yearmonth=189509, pcp=0.82)
# Row(yearmonth=190812, pcp=0.82)
# Row(yearmonth=193210, pcp=0.82)
# Row(yearmonth=196104, pcp=0.82)
# Row(yearmonth=190411, pcp=0.81)
# Row(yearmonth=191802, pcp=0.81)
# Row(yearmonth=196702, pcp=0.81)
# Row(yearmonth=200412, pcp=0.81)
# Row(yearmonth=191711, pcp=0.8)
# Row(yearmonth=196612, pcp=0.8)
# Row(yearmonth=200104, pcp=0.79)
# Row(yearmonth=200304, pcp=0.77)
# Row(yearmonth=190202, pcp=0.76)
# Row(yearmonth=191106, pcp=0.76)
# Row(yearmonth=191801, pcp=0.76)
# Row(yearmonth=195503, pcp=0.76)
# Row(yearmonth=201010, pcp=0.76)
# Row(yearmonth=191702, pcp=0.75)
# Row(yearmonth=195412, pcp=0.75)
# Row(yearmonth=198911, pcp=0.75)
# Row(yearmonth=199603, pcp=0.75)
# Row(yearmonth=189605, pcp=0.74)
# Row(yearmonth=191511, pcp=0.74)
# Row(yearmonth=192410, pcp=0.74)
# Row(yearmonth=195201, pcp=0.74)
# Row(yearmonth=198710, pcp=0.74)
# Row(yearmonth=201107, pcp=0.74)
# Row(yearmonth=201108, pcp=0.74)
# Row(yearmonth=191703, pcp=0.73)
# Row(yearmonth=196202, pcp=0.73)
# Row(yearmonth=196603, pcp=0.73)
# Row(yearmonth=200511, pcp=0.73)
# Row(yearmonth=201012, pcp=0.73)
# Row(yearmonth=201402, pcp=0.73)
# Row(yearmonth=191706, pcp=0.72)
# Row(yearmonth=194001, pcp=0.72)
# Row(yearmonth=194812, pcp=0.72)
# Row(yearmonth=200611, pcp=0.72)
# Row(yearmonth=190902, pcp=0.71)
# Row(yearmonth=193306, pcp=0.71)
# Row(yearmonth=196901, pcp=0.71)
# Row(yearmonth=200312, pcp=0.71)
# Row(yearmonth=189908, pcp=0.7)
# Row(yearmonth=195112, pcp=0.7)
# Row(yearmonth=199805, pcp=0.7)
# Row(yearmonth=200007, pcp=0.7)
# Row(yearmonth=200504, pcp=0.7)
# Row(yearmonth=201104, pcp=0.7)
# Row(yearmonth=194511, pcp=0.69)
# Row(yearmonth=201210, pcp=0.69)
# Row(yearmonth=201610, pcp=0.69)
# Row(yearmonth=190201, pcp=0.68)
# Row(yearmonth=198912, pcp=0.67)
# Row(yearmonth=199804, pcp=0.67)
# Row(yearmonth=190208, pcp=0.66)
# Row(yearmonth=190403, pcp=0.66)
# Row(yearmonth=195512, pcp=0.66)
# Row(yearmonth=201303, pcp=0.66)
# Row(yearmonth=191001, pcp=0.65)
# Row(yearmonth=193601, pcp=0.65)
# Row(yearmonth=198007, pcp=0.65)
# Row(yearmonth=201102, pcp=0.65)
# Row(yearmonth=193211, pcp=0.64)
# Row(yearmonth=195511, pcp=0.64)
# Row(yearmonth=191603, pcp=0.63)
# Row(yearmonth=192002, pcp=0.63)
# Row(yearmonth=200902, pcp=0.62)
# Row(yearmonth=192111, pcp=0.61)
# Row(yearmonth=189903, pcp=0.59)
# Row(yearmonth=191011, pcp=0.59)
# Row(yearmonth=195903, pcp=0.59)
# Row(yearmonth=198404, pcp=0.59)
# Row(yearmonth=198801, pcp=0.59)
# Row(yearmonth=198603, pcp=0.58)
# Row(yearmonth=200301, pcp=0.58)
# Row(yearmonth=193109, pcp=0.57)
# Row(yearmonth=193602, pcp=0.57)
# Row(yearmonth=195003, pcp=0.57)
# Row(yearmonth=195301, pcp=0.57)
# Row(yearmonth=198304, pcp=0.57)
# Row(yearmonth=190401, pcp=0.56)
# Row(yearmonth=192503, pcp=0.56)
# Row(yearmonth=197712, pcp=0.56)
# Row(yearmonth=195208, pcp=0.55)
# Row(yearmonth=192411, pcp=0.54)
# Row(yearmonth=195609, pcp=0.54)
# Row(yearmonth=189902, pcp=0.53)
# Row(yearmonth=191612, pcp=0.53)
# Row(yearmonth=194201, pcp=0.53)
# Row(yearmonth=197402, pcp=0.53)
# Row(yearmonth=192801, pcp=0.52)
# Row(yearmonth=196303, pcp=0.52)
# Row(yearmonth=197202, pcp=0.52)
# Row(yearmonth=200812, pcp=0.52)
# Row(yearmonth=193702, pcp=0.51)
# Row(yearmonth=196701, pcp=0.51)
# Row(yearmonth=195010, pcp=0.5)
# Row(yearmonth=196301, pcp=0.5)
# Row(yearmonth=197012, pcp=0.49)
# Row(yearmonth=199601, pcp=0.49)
# Row(yearmonth=194308, pcp=0.48)
# Row(yearmonth=197601, pcp=0.48)
# Row(yearmonth=198112, pcp=0.48)
# Row(yearmonth=198601, pcp=0.48)
# Row(yearmonth=200702, pcp=0.48)
# Row(yearmonth=200008, pcp=0.47)
# Row(yearmonth=190101, pcp=0.46)
# Row(yearmonth=195901, pcp=0.45)
# Row(yearmonth=200512, pcp=0.45)
# Row(yearmonth=189702, pcp=0.44)
# Row(yearmonth=192110, pcp=0.44)
# Row(yearmonth=194702, pcp=0.44)
# Row(yearmonth=197602, pcp=0.44)
# Row(yearmonth=192711, pcp=0.43)
# Row(yearmonth=195603, pcp=0.43)
# Row(yearmonth=189711, pcp=0.42)
# Row(yearmonth=191101, pcp=0.41)
# Row(yearmonth=191201, pcp=0.41)
# Row(yearmonth=192212, pcp=0.41)
# Row(yearmonth=197011, pcp=0.4)
# Row(yearmonth=200901, pcp=0.4)
# Row(yearmonth=195403, pcp=0.38)
# Row(yearmonth=194302, pcp=0.37)
# Row(yearmonth=201401, pcp=0.37)
# Row(yearmonth=193410, pcp=0.36)
# Row(yearmonth=192502, pcp=0.35)
# Row(yearmonth=196611, pcp=0.35)
# Row(yearmonth=195011, pcp=0.32)
# Row(yearmonth=201211, pcp=0.31)
# Row(yearmonth=195402, pcp=0.29)
# Row(yearmonth=191401, pcp=0.28)
# Row(yearmonth=197103, pcp=0.28)
# Row(yearmonth=191710, pcp=0.27)
# Row(yearmonth=201103, pcp=0.27)
# Row(yearmonth=199911, pcp=0.26)
# Row(yearmonth=192602, pcp=0.25)
# Row(yearmonth=199602, pcp=0.25)
# Row(yearmonth=195012, pcp=0.24)
# Row(yearmonth=199902, pcp=0.23)
# Row(yearmonth=197101, pcp=0.16)
# Row(yearmonth=191712, pcp=0.15)
# Row(yearmonth=190901, pcp=0.14)
# Row(yearmonth=194911, pcp=0.12)
# Row(yearmonth=190311, pcp=0.11)
# Row(yearmonth=191602, pcp=0.08)
# Row(yearmonth=195210, pcp=0.02)

# %% [markdown]
# From the data collected, we found: the highest PCP is 9.05 in 05/2015, and lowest PCP is 0.02 in 10/1952.
